# %% [markdown]
# **Date**: 1 April 2026
# **Objective**: Checkout the breeze-connect api provided by ICICI for market data

# %% [markdown]
# ## **Import**

# %%
import os
from pathlib import Path

from breeze_connect import BreezeConnect
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# env_path = Path.cwd()
# for candidate in [Path.cwd(), *Path.cwd().parents]:
#     maybe_env = candidate / ".env"
#     if maybe_env.exists():
#         env_path = maybe_env
#         break


breeze_api_key = os.getenv("BREEZE_API_KEY")
breeze_api_secret = os.getenv("BREEZE_API_SECRET")
breeze_session_token = os.getenv("BREEZE_SESSION_TOKEN")

missing = [
    name
    for name, value in {
        "BREEZE_API_KEY": breeze_api_key,
        "BREEZE_API_SECRET": breeze_api_secret,
        "BREEZE_SESSION_TOKEN": breeze_session_token,
    }.items()
    if not value
]

if missing:
    raise ValueError(f"Missing Breeze env vars: {', '.join(missing)}")

# %%
breeze = BreezeConnect(api_key=breeze_api_key)
breeze.generate_session(api_secret=breeze_api_secret, session_token=breeze_session_token)
breeze

# %%
data=breeze.get_historical_data_v2(interval="1second",
                    from_date= "2026-02-03T09:20:00.000Z",
                    to_date= "2026-06-03T09:22:00.000Z",
                    stock_code="RELIND",
                    exchange_code="NSE",
                    product_type="cash")

# %%
nifty_24200_ce_params = {
    "interval": "1minute",
    "from_date": "2026-04-28T09:15:00.000Z",
    "to_date": "2026-04-28T15:30:00.000Z",
    "stock_code": "NIFTY",
    "exchange_code": "NFO",
    "product_type": "options",
    "expiry_date": "2026-04-28T07:00:00.000Z",
    "right": "call",
    "strike_price": "24200",
}

nifty_24200_ce_data = breeze.get_historical_data_v2(**nifty_24200_ce_params)

# %%
nifty_24200_ce_data
# Out:
# {'Error': None,
#  'Status': 200,
#  'Success': [{'close': 9.3,
#    'datetime': '2026-04-28 09:15:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 19.9,
#    'low': 5.25,
#    'open': 17.75,
#    'open_interest': 7206420,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 9162140},
#   {'close': 12.95,
#    'datetime': '2026-04-28 09:16:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 15.5,
#    'low': 8.05,
#    'open': 9.55,
#    'open_interest': 9315020,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 9418890},
#   {'close': 12.6,
#    'datetime': '2026-04-28 09:17:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 15.65,
#    'low': 12.45,
#    'open': 14.65,
#    'open_interest': 9315020,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 5125640},
#   {'close': 16.8,
#    'datetime': '2026-04-28 09:18:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 16.9,
#    'low': 11.7,
#    'open': 12.85,
#    'open_interest': 9315020,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4929470},
#   {'close': 19.75,
#    'datetime': '2026-04-28 09:19:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 21.4,
#    'low': 16.85,
#    'open': 16.85,
#    'open_interest': 10868520,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 6287255},
#   {'close': 22.15,
#    'datetime': '2026-04-28 09:20:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 24.5,
#    'low': 19.05,
#    'open': 19.9,
#    'open_interest': 10868520,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 6078865},
#   {'close': 21.55,
#    'datetime': '2026-04-28 09:21:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 22.95,
#    'low': 18.05,
#    'open': 21.8,
#    'open_interest': 10868520,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4368910},
#   {'close': 20.65,
#    'datetime': '2026-04-28 09:22:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 22.05,
#    'low': 19.2,
#    'open': 21.1,
#    'open_interest': 12247495,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2935270},
#   {'close': 19.95,
#    'datetime': '2026-04-28 09:23:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 22.45,
#    'low': 19.2,
#    'open': 21.2,
#    'open_interest': 12247495,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2849080},
#   {'close': 18.5,
#    'datetime': '2026-04-28 09:24:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 20.1,
#    'low': 16.25,
#    'open': 19.9,
#    'open_interest': 12247495,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3646435},
#   {'close': 28.5,
#    'datetime': '2026-04-28 09:25:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 28.9,
#    'low': 18.35,
#    'open': 18.35,
#    'open_interest': 13332800,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 6549465},
#   {'close': 31.35,
#    'datetime': '2026-04-28 09:26:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 33.3,
#    'low': 28.65,
#    'open': 28.9,
#    'open_interest': 13332800,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 7935655},
#   {'close': 26.8,
#    'datetime': '2026-04-28 09:27:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 31.15,
#    'low': 26.05,
#    'open': 31.15,
#    'open_interest': 13332800,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4403230},
#   {'close': 27.6,
#    'datetime': '2026-04-28 09:28:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 27.8,
#    'low': 24.95,
#    'open': 26.8,
#    'open_interest': 13196235,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3150745},
#   {'close': 24.35,
#    'datetime': '2026-04-28 09:29:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 28.25,
#    'low': 24.05,
#    'open': 27.55,
#    'open_interest': 13196235,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3042520},
#   {'close': 22.5,
#    'datetime': '2026-04-28 09:30:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 27.55,
#    'low': 21.9,
#    'open': 24.6,
#    'open_interest': 13196235,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4197180},
#   {'close': 21.6,
#    'datetime': '2026-04-28 09:31:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 23.7,
#    'low': 21.0,
#    'open': 22.8,
#    'open_interest': 14454505,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3100565},
#   {'close': 22.0,
#    'datetime': '2026-04-28 09:32:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 23.7,
#    'low': 20.85,
#    'open': 21.9,
#    'open_interest': 14454505,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2744040},
#   {'close': 24.45,
#    'datetime': '2026-04-28 09:33:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 25.1,
#    'low': 20.7,
#    'open': 22.05,
#    'open_interest': 14454505,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3520465},
#   {'close': 22.25,
#    'datetime': '2026-04-28 09:34:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 26.1,
#    'low': 21.85,
#    'open': 24.4,
#    'open_interest': 15761200,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3789110},
#   {'close': 18.25,
#    'datetime': '2026-04-28 09:35:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 21.9,
#    'low': 17.75,
#    'open': 21.8,
#    'open_interest': 15761200,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 5543135},
#   {'close': 22.55,
#    'datetime': '2026-04-28 09:36:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 23.05,
#    'low': 17.7,
#    'open': 17.95,
#    'open_interest': 15761200,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3341130},
#   {'close': 23.3,
#    'datetime': '2026-04-28 09:37:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 25.5,
#    'low': 21.95,
#    'open': 23.0,
#    'open_interest': 16513835,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4130685},
#   {'close': 21.6,
#    'datetime': '2026-04-28 09:38:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 23.7,
#    'low': 20.5,
#    'open': 23.7,
#    'open_interest': 16513835,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2426970},
#   {'close': 19.9,
#    'datetime': '2026-04-28 09:39:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 22.0,
#    'low': 18.4,
#    'open': 21.6,
#    'open_interest': 16513835,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2604940},
#   {'close': 22.75,
#    'datetime': '2026-04-28 09:40:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 24.1,
#    'low': 19.2,
#    'open': 20.0,
#    'open_interest': 17089085,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3166670},
#   {'close': 24.55,
#    'datetime': '2026-04-28 09:41:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 25.2,
#    'low': 22.0,
#    'open': 22.8,
#    'open_interest': 17089085,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3998280},
#   {'close': 22.8,
#    'datetime': '2026-04-28 09:42:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 25.8,
#    'low': 22.65,
#    'open': 24.15,
#    'open_interest': 17089085,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3804450},
#   {'close': 24.55,
#    'datetime': '2026-04-28 09:43:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 25.65,
#    'low': 22.7,
#    'open': 22.9,
#    'open_interest': 17954235,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3105310},
#   {'close': 26.3,
#    'datetime': '2026-04-28 09:44:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 27.65,
#    'low': 24.95,
#    'open': 25.35,
#    'open_interest': 17954235,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3980015},
#   {'close': 29.9,
#    'datetime': '2026-04-28 09:45:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 31.05,
#    'low': 26.3,
#    'open': 26.65,
#    'open_interest': 17954235,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 6742190},
#   {'close': 31.6,
#    'datetime': '2026-04-28 09:46:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 33.65,
#    'low': 29.35,
#    'open': 29.35,
#    'open_interest': 16892460,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 7268755},
#   {'close': 29.0,
#    'datetime': '2026-04-28 09:47:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 31.2,
#    'low': 27.9,
#    'open': 31.2,
#    'open_interest': 16892460,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3778060},
#   {'close': 25.3,
#    'datetime': '2026-04-28 09:48:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 29.7,
#    'low': 23.6,
#    'open': 29.15,
#    'open_interest': 16892460,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4608825},
#   {'close': 20.9,
#    'datetime': '2026-04-28 09:49:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 24.9,
#    'low': 20.9,
#    'open': 24.85,
#    'open_interest': 17276480,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3839095},
#   {'close': 21.6,
#    'datetime': '2026-04-28 09:50:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 24.1,
#    'low': 20.75,
#    'open': 20.8,
#    'open_interest': 17276480,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3453190},
#   {'close': 21.1,
#    'datetime': '2026-04-28 09:51:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 22.45,
#    'low': 20.95,
#    'open': 21.65,
#    'open_interest': 17276480,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 1996280},
#   {'close': 20.6,
#    'datetime': '2026-04-28 09:52:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 21.25,
#    'low': 19.0,
#    'open': 21.1,
#    'open_interest': 18211245,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3303690},
#   {'close': 20.1,
#    'datetime': '2026-04-28 09:53:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 20.8,
#    'low': 18.95,
#    'open': 20.55,
#    'open_interest': 18211245,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 1980940},
#   {'close': 22.6,
#    'datetime': '2026-04-28 09:54:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 22.85,
#    'low': 19.1,
#    'open': 20.3,
#    'open_interest': 18211245,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2162875},
#   {'close': 24.85,
#    'datetime': '2026-04-28 09:55:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 26.2,
#    'low': 22.1,
#    'open': 22.1,
#    'open_interest': 18973240,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 5474170},
#   {'close': 24.75,
#    'datetime': '2026-04-28 09:56:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 26.4,
#    'low': 24.35,
#    'open': 25.05,
#    'open_interest': 18973240,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3478475},
#   {'close': 24.0,
#    'datetime': '2026-04-28 09:57:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 25.65,
#    'low': 23.55,
#    'open': 24.9,
#    'open_interest': 18973240,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3001505},
#   {'close': 26.85,
#    'datetime': '2026-04-28 09:58:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 27.3,
#    'low': 23.55,
#    'open': 24.2,
#    'open_interest': 20207135,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3680300},
#   {'close': 29.85,
#    'datetime': '2026-04-28 09:59:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 30.95,
#    'low': 25.5,
#    'open': 26.9,
#    'open_interest': 20207135,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 6818760},
#   {'close': 31.15,
#    'datetime': '2026-04-28 10:00:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 31.9,
#    'low': 29.25,
#    'open': 29.85,
#    'open_interest': 20207135,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 6850155},
#   {'close': 31.2,
#    'datetime': '2026-04-28 10:01:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 33.45,
#    'low': 30.95,
#    'open': 31.5,
#    'open_interest': 19159725,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 6104410},
#   {'close': 30.3,
#    'datetime': '2026-04-28 10:02:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 32.4,
#    'low': 29.9,
#    'open': 31.35,
#    'open_interest': 19159725,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4198480},
#   {'close': 30.4,
#    'datetime': '2026-04-28 10:03:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 31.2,
#    'low': 27.45,
#    'open': 30.4,
#    'open_interest': 19159725,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4412460},
#   {'close': 28.55,
#    'datetime': '2026-04-28 10:04:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 30.25,
#    'low': 27.8,
#    'open': 30.25,
#    'open_interest': 19476210,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3082690},
#   {'close': 25.65,
#    'datetime': '2026-04-28 10:05:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 28.55,
#    'low': 25.6,
#    'open': 28.4,
#    'open_interest': 19476210,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3732040},
#   {'close': 24.85,
#    'datetime': '2026-04-28 10:06:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 26.1,
#    'low': 23.65,
#    'open': 25.65,
#    'open_interest': 19476210,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4276155},
#   {'close': 27.5,
#    'datetime': '2026-04-28 10:07:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 28.75,
#    'low': 23.6,
#    'open': 24.45,
#    'open_interest': 20251335,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4089735},
#   {'close': 28.75,
#    'datetime': '2026-04-28 10:08:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 29.6,
#    'low': 27.25,
#    'open': 27.65,
#    'open_interest': 20251335,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3915470},
#   {'close': 28.25,
#    'datetime': '2026-04-28 10:09:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 30.2,
#    'low': 27.75,
#    'open': 28.6,
#    'open_interest': 20251335,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3324750},
#   {'close': 27.45,
#    'datetime': '2026-04-28 10:10:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 28.85,
#    'low': 26.25,
#    'open': 28.0,
#    'open_interest': 21393125,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2735460},
#   {'close': 24.8,
#    'datetime': '2026-04-28 10:11:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 27.4,
#    'low': 24.8,
#    'open': 27.15,
#    'open_interest': 21393125,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3014050},
#   {'close': 24.85,
#    'datetime': '2026-04-28 10:12:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 25.0,
#    'low': 23.8,
#    'open': 24.95,
#    'open_interest': 21393125,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2704715},
#   {'close': 22.7,
#    'datetime': '2026-04-28 10:13:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 25.85,
#    'low': 22.25,
#    'open': 25.45,
#    'open_interest': 21915855,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3444675},
#   {'close': 24.1,
#    'datetime': '2026-04-28 10:14:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 24.65,
#    'low': 22.2,
#    'open': 22.5,
#    'open_interest': 21915855,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2010840},
#   {'close': 26.05,
#    'datetime': '2026-04-28 10:15:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 26.7,
#    'low': 21.9,
#    'open': 23.75,
#    'open_interest': 21915855,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3711175},
#   {'close': 27.95,
#    'datetime': '2026-04-28 10:16:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 28.8,
#    'low': 25.9,
#    'open': 25.9,
#    'open_interest': 22440405,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4882085},
#   {'close': 26.85,
#    'datetime': '2026-04-28 10:17:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 28.45,
#    'low': 24.9,
#    'open': 27.95,
#    'open_interest': 22440405,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3183830},
#   {'close': 27.15,
#    'datetime': '2026-04-28 10:18:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 27.15,
#    'low': 23.35,
#    'open': 26.7,
#    'open_interest': 22440405,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3068780},
#   {'close': 26.4,
#    'datetime': '2026-04-28 10:19:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 27.25,
#    'low': 25.6,
#    'open': 27.15,
#    'open_interest': 23234120,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2070120},
#   {'close': 26.9,
#    'datetime': '2026-04-28 10:20:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 27.0,
#    'low': 24.35,
#    'open': 25.6,
#    'open_interest': 23234120,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2223260},
#   {'close': 29.0,
#    'datetime': '2026-04-28 10:21:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 29.05,
#    'low': 26.3,
#    'open': 26.35,
#    'open_interest': 23234120,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4069780},
#   {'close': 28.7,
#    'datetime': '2026-04-28 10:22:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 31.25,
#    'low': 28.0,
#    'open': 29.1,
#    'open_interest': 23275655,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 5796895},
#   {'close': 26.7,
#    'datetime': '2026-04-28 10:23:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 28.55,
#    'low': 25.45,
#    'open': 28.45,
#    'open_interest': 23275655,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4304495},
#   {'close': 27.25,
#    'datetime': '2026-04-28 10:24:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 28.2,
#    'low': 25.45,
#    'open': 26.5,
#    'open_interest': 23275655,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2620995},
#   {'close': 30.25,
#    'datetime': '2026-04-28 10:25:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 30.35,
#    'low': 26.9,
#    'open': 27.25,
#    'open_interest': 24169470,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3588780},
#   {'close': 27.8,
#    'datetime': '2026-04-28 10:26:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 31.15,
#    'low': 27.8,
#    'open': 30.7,
#    'open_interest': 24169470,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4812665},
#   {'close': 25.9,
#    'datetime': '2026-04-28 10:27:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 28.0,
#    'low': 25.4,
#    'open': 28.0,
#    'open_interest': 24169470,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3963115},
#   {'close': 25.35,
#    'datetime': '2026-04-28 10:28:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 25.9,
#    'low': 23.6,
#    'open': 25.9,
#    'open_interest': 24353615,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4168710},
#   {'close': 25.5,
#    'datetime': '2026-04-28 10:29:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 26.1,
#    'low': 24.9,
#    'open': 25.65,
#    'open_interest': 24353615,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2052050},
#   {'close': 26.35,
#    'datetime': '2026-04-28 10:30:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 26.7,
#    'low': 24.7,
#    'open': 25.35,
#    'open_interest': 24353615,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2855970},
#   {'close': 22.95,
#    'datetime': '2026-04-28 10:31:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 25.45,
#    'low': 22.9,
#    'open': 25.2,
#    'open_interest': 25406485,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3688360},
#   {'close': 22.15,
#    'datetime': '2026-04-28 10:32:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 23.8,
#    'low': 21.95,
#    'open': 23.35,
#    'open_interest': 25406485,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3387735},
#   {'close': 21.25,
#    'datetime': '2026-04-28 10:33:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 22.2,
#    'low': 21.1,
#    'open': 22.0,
#    'open_interest': 25406485,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3231085},
#   {'close': 21.15,
#    'datetime': '2026-04-28 10:34:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 21.25,
#    'low': 20.05,
#    'open': 21.15,
#    'open_interest': 25357930,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3731650},
#   {'close': 18.45,
#    'datetime': '2026-04-28 10:35:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 21.2,
#    'low': 17.35,
#    'open': 20.9,
#    'open_interest': 25357930,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 6460675},
#   {'close': 19.4,
#    'datetime': '2026-04-28 10:36:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 19.4,
#    'low': 17.55,
#    'open': 18.5,
#    'open_interest': 25357930,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3814785},
#   {'close': 17.1,
#    'datetime': '2026-04-28 10:37:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 19.85,
#    'low': 16.9,
#    'open': 19.65,
#    'open_interest': 25949755,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3559855},
#   {'close': 17.05,
#    'datetime': '2026-04-28 10:38:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 17.75,
#    'low': 16.6,
#    'open': 17.2,
#    'open_interest': 25949755,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3217630},
#   {'close': 18.2,
#    'datetime': '2026-04-28 10:39:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 18.65,
#    'low': 16.75,
#    'open': 17.25,
#    'open_interest': 25949755,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2284425},
#   {'close': 17.85,
#    'datetime': '2026-04-28 10:40:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 18.3,
#    'low': 17.05,
#    'open': 17.9,
#    'open_interest': 26224900,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 1906125},
#   {'close': 16.5,
#    'datetime': '2026-04-28 10:41:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 17.8,
#    'low': 15.45,
#    'open': 17.75,
#    'open_interest': 26224900,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4611295},
#   {'close': 16.15,
#    'datetime': '2026-04-28 10:42:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 17.05,
#    'low': 15.3,
#    'open': 16.7,
#    'open_interest': 26224900,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3181425},
#   {'close': 17.15,
#    'datetime': '2026-04-28 10:43:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 17.5,
#    'low': 16.15,
#    'open': 16.25,
#    'open_interest': 25864020,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2477735},
#   {'close': 17.95,
#    'datetime': '2026-04-28 10:44:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 18.05,
#    'low': 15.9,
#    'open': 17.25,
#    'open_interest': 25864020,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2108405},
#   {'close': 21.4,
#    'datetime': '2026-04-28 10:45:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 21.4,
#    'low': 17.25,
#    'open': 18.05,
#    'open_interest': 25864020,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 5529160},
#   {'close': 21.3,
#    'datetime': '2026-04-28 10:46:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 21.65,
#    'low': 19.3,
#    'open': 21.05,
#    'open_interest': 27041885,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 5709600},
#   {'close': 20.15,
#    'datetime': '2026-04-28 10:47:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 21.7,
#    'low': 18.4,
#    'open': 21.6,
#    'open_interest': 27041885,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4158700},
#   {'close': 20.0,
#    'datetime': '2026-04-28 10:48:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 21.1,
#    'low': 19.7,
#    'open': 20.15,
#    'open_interest': 27041885,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3136575},
#   {'close': 20.45,
#    'datetime': '2026-04-28 10:49:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 20.5,
#    'low': 18.9,
#    'open': 20.1,
#    'open_interest': 27870960,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2423850},
#   {'close': 21.2,
#    'datetime': '2026-04-28 10:50:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 22.1,
#    'low': 20.0,
#    'open': 20.4,
#    'open_interest': 27870960,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4480905},
#   {'close': 20.15,
#    'datetime': '2026-04-28 10:51:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 21.15,
#    'low': 19.85,
#    'open': 21.1,
#    'open_interest': 27870960,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2438215},
#   {'close': 20.4,
#    'datetime': '2026-04-28 10:52:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 21.05,
#    'low': 19.9,
#    'open': 20.35,
#    'open_interest': 28417220,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 1840020},
#   {'close': 20.6,
#    'datetime': '2026-04-28 10:53:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 21.6,
#    'low': 20.15,
#    'open': 20.5,
#    'open_interest': 28417220,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2824770},
#   {'close': 24.05,
#    'datetime': '2026-04-28 10:54:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 26.15,
#    'low': 20.25,
#    'open': 20.7,
#    'open_interest': 28417220,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 6434220},
#   {'close': 26.55,
#    'datetime': '2026-04-28 10:55:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 27.75,
#    'low': 24.15,
#    'open': 24.2,
#    'open_interest': 26418405,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 8906105},
#   {'close': 27.1,
#    'datetime': '2026-04-28 10:56:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 27.65,
#    'low': 25.7,
#    'open': 26.95,
#    'open_interest': 26418405,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 5187845},
#   {'close': 22.8,
#    'datetime': '2026-04-28 10:57:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 27.0,
#    'low': 22.4,
#    'open': 27.0,
#    'open_interest': 26418405,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 5840575},
#   {'close': 23.3,
#    'datetime': '2026-04-28 10:58:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 24.85,
#    'low': 22.7,
#    'open': 22.7,
#    'open_interest': 26760890,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3206060},
#   {'close': 23.2,
#    'datetime': '2026-04-28 10:59:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 24.1,
#    'low': 22.25,
#    'open': 23.2,
#    'open_interest': 26760890,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2804750},
#   {'close': 20.85,
#    'datetime': '2026-04-28 11:00:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 23.05,
#    'low': 20.1,
#    'open': 23.05,
#    'open_interest': 26760890,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4911270},
#   {'close': 20.7,
#    'datetime': '2026-04-28 11:01:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 22.15,
#    'low': 20.65,
#    'open': 20.85,
#    'open_interest': 27560195,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2558140},
#   {'close': 19.15,
#    'datetime': '2026-04-28 11:02:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 22.15,
#    'low': 18.4,
#    'open': 21.15,
#    'open_interest': 27560195,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4529720},
#   {'close': 20.5,
#    'datetime': '2026-04-28 11:03:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 20.9,
#    'low': 18.55,
#    'open': 19.15,
#    'open_interest': 27560195,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3460340},
#   {'close': 20.3,
#    'datetime': '2026-04-28 11:04:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 20.85,
#    'low': 19.65,
#    'open': 20.65,
#    'open_interest': 27992055,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2089425},
#   {'close': 16.95,
#    'datetime': '2026-04-28 11:05:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 20.45,
#    'low': 16.95,
#    'open': 20.45,
#    'open_interest': 27992055,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4452175},
#   {'close': 16.7,
#    'datetime': '2026-04-28 11:06:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 17.55,
#    'low': 15.5,
#    'open': 17.45,
#    'open_interest': 27992055,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 5543070},
#   {'close': 15.45,
#    'datetime': '2026-04-28 11:07:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 16.7,
#    'low': 14.85,
#    'open': 16.7,
#    'open_interest': 27620710,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4694625},
#   {'close': 16.65,
#    'datetime': '2026-04-28 11:08:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 16.95,
#    'low': 15.2,
#    'open': 15.6,
#    'open_interest': 27620710,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3913260},
#   {'close': 17.1,
#    'datetime': '2026-04-28 11:09:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 17.5,
#    'low': 16.45,
#    'open': 16.55,
#    'open_interest': 27620710,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3170700},
#   {'close': 16.8,
#    'datetime': '2026-04-28 11:10:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 17.6,
#    'low': 16.55,
#    'open': 16.9,
#    'open_interest': 28411955,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2256475},
#   {'close': 13.7,
#    'datetime': '2026-04-28 11:11:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 17.1,
#    'low': 13.6,
#    'open': 17.1,
#    'open_interest': 28411955,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4342975},
#   {'close': 15.35,
#    'datetime': '2026-04-28 11:12:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 15.35,
#    'low': 13.05,
#    'open': 13.6,
#    'open_interest': 28411955,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4568460},
#   {'close': 16.65,
#    'datetime': '2026-04-28 11:13:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 16.85,
#    'low': 15.45,
#    'open': 15.6,
#    'open_interest': 28534155,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3485235},
#   {'close': 16.3,
#    'datetime': '2026-04-28 11:14:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 17.4,
#    'low': 16.1,
#    'open': 16.65,
#    'open_interest': 28534155,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2541045},
#   {'close': 14.25,
#    'datetime': '2026-04-28 11:15:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 16.45,
#    'low': 14.25,
#    'open': 16.35,
#    'open_interest': 28534155,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2707835},
#   {'close': 13.1,
#    'datetime': '2026-04-28 11:16:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 15.3,
#    'low': 13.1,
#    'open': 14.35,
#    'open_interest': 28827825,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3243565},
#   {'close': 13.45,
#    'datetime': '2026-04-28 11:17:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 13.6,
#    'low': 12.45,
#    'open': 12.9,
#    'open_interest': 28827825,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4156425},
#   {'close': 13.35,
#    'datetime': '2026-04-28 11:18:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 14.1,
#    'low': 13.1,
#    'open': 13.55,
#    'open_interest': 28827825,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2492945},
#   {'close': 13.35,
#    'datetime': '2026-04-28 11:19:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 13.6,
#    'low': 13.05,
#    'open': 13.25,
#    'open_interest': 29213405,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 1549730},
#   {'close': 14.3,
#    'datetime': '2026-04-28 11:20:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 14.7,
#    'low': 13.5,
#    'open': 13.5,
#    'open_interest': 29213405,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2252575},
#   {'close': 14.3,
#    'datetime': '2026-04-28 11:21:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 15.15,
#    'low': 14.05,
#    'open': 14.15,
#    'open_interest': 29213405,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2625025},
#   {'close': 13.0,
#    'datetime': '2026-04-28 11:22:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 14.9,
#    'low': 12.95,
#    'open': 14.45,
#    'open_interest': 29668860,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2204150},
#   {'close': 12.05,
#    'datetime': '2026-04-28 11:23:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 13.25,
#    'low': 11.45,
#    'open': 13.0,
#    'open_interest': 29668860,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4858620},
#   {'close': 10.3,
#    'datetime': '2026-04-28 11:24:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 11.95,
#    'low': 10.0,
#    'open': 11.95,
#    'open_interest': 29668860,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 6916650},
#   {'close': 8.5,
#    'datetime': '2026-04-28 11:25:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 10.05,
#    'low': 8.5,
#    'open': 9.95,
#    'open_interest': 27683305,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 7962305},
#   {'close': 8.0,
#    'datetime': '2026-04-28 11:26:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 8.8,
#    'low': 7.95,
#    'open': 8.55,
#    'open_interest': 27683305,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 6524245},
#   {'close': 7.7,
#    'datetime': '2026-04-28 11:27:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 8.2,
#    'low': 7.6,
#    'open': 8.0,
#    'open_interest': 27683305,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 7328685},
#   {'close': 7.5,
#    'datetime': '2026-04-28 11:28:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 7.9,
#    'low': 6.8,
#    'open': 7.7,
#    'open_interest': 26805740,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 7101770},
#   {'close': 6.5,
#    'datetime': '2026-04-28 11:29:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 7.55,
#    'low': 6.5,
#    'open': 7.55,
#    'open_interest': 26805740,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4863560},
#   {'close': 6.05,
#    'datetime': '2026-04-28 11:30:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 6.5,
#    'low': 6.0,
#    'open': 6.5,
#    'open_interest': 26805740,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 6817980},
#   {'close': 6.7,
#    'datetime': '2026-04-28 11:31:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 6.8,
#    'low': 5.9,
#    'open': 6.1,
#    'open_interest': 27523210,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4979585},
#   {'close': 6.3,
#    'datetime': '2026-04-28 11:32:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 7.05,
#    'low': 6.3,
#    'open': 6.7,
#    'open_interest': 27523210,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3028610},
#   {'close': 5.55,
#    'datetime': '2026-04-28 11:33:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 6.3,
#    'low': 5.5,
#    'open': 6.3,
#    'open_interest': 27523210,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3797690},
#   {'close': 6.05,
#    'datetime': '2026-04-28 11:34:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 6.1,
#    'low': 5.65,
#    'open': 5.65,
#    'open_interest': 28541760,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2466035},
#   {'close': 6.2,
#    'datetime': '2026-04-28 11:35:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 6.3,
#    'low': 5.95,
#    'open': 6.05,
#    'open_interest': 28541760,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2996565},
#   {'close': 7.15,
#    'datetime': '2026-04-28 11:36:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 7.15,
#    'low': 6.1,
#    'open': 6.25,
#    'open_interest': 28541760,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2880345},
#   {'close': 7.1,
#    'datetime': '2026-04-28 11:37:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 7.4,
#    'low': 6.85,
#    'open': 7.25,
#    'open_interest': 30862780,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 3749655},
#   {'close': 6.95,
#    'datetime': '2026-04-28 11:38:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 7.75,
#    'low': 6.45,
#    'open': 7.1,
#    'open_interest': 30862780,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4212585},
#   {'close': 7.3,
#    'datetime': '2026-04-28 11:39:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 7.5,
#    'low': 6.9,
#    'open': 7.05,
#    'open_interest': 30862780,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2446730},
#   {'close': 6.95,
#    'datetime': '2026-04-28 11:40:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 7.95,
#    'low': 6.9,
#    'open': 7.3,
#    'open_interest': 31398835,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 4049305},
#   {'close': 6.8,
#    'datetime': '2026-04-28 11:41:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 7.15,
#    'low': 6.5,
#    'open': 6.9,
#    'open_interest': 31398835,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2793765},
#   {'close': 6.5,
#    'datetime': '2026-04-28 11:42:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 6.95,
#    'low': 6.1,
#    'open': 6.85,
#    'open_interest': 31398835,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
# ...
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.45,
#    'low': 0.4,
#    'open': 0.45,
#    'open_interest': 17781465,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 748605},
#   {'close': 0.45,
#    'datetime': '2026-04-28 14:41:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.45,
#    'low': 0.4,
#    'open': 0.4,
#    'open_interest': 17339985,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 831675},
#   {'close': 0.4,
#    'datetime': '2026-04-28 14:42:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.4,
#    'low': 0.35,
#    'open': 0.4,
#    'open_interest': 17339985,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 1632280},
#   {'close': 0.4,
#    'datetime': '2026-04-28 14:43:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.4,
#    'low': 0.35,
#    'open': 0.35,
#    'open_interest': 17339985,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 1069510},
#   {'close': 0.4,
#    'datetime': '2026-04-28 14:44:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.4,
#    'low': 0.35,
#    'open': 0.4,
#    'open_interest': 16724695,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 787150},
#   {'close': 0.35,
#    'datetime': '2026-04-28 14:45:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.4,
#    'low': 0.35,
#    'open': 0.35,
#    'open_interest': 16724695,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 777270},
#   {'close': 0.4,
#    'datetime': '2026-04-28 14:46:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.4,
#    'low': 0.35,
#    'open': 0.35,
#    'open_interest': 16724695,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 221130},
#   {'close': 0.35,
#    'datetime': '2026-04-28 14:47:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.4,
#    'low': 0.35,
#    'open': 0.35,
#    'open_interest': 16528720,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 546000},
#   {'close': 0.3,
#    'datetime': '2026-04-28 14:48:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.4,
#    'low': 0.3,
#    'open': 0.4,
#    'open_interest': 16528720,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 630110},
#   {'close': 0.35,
#    'datetime': '2026-04-28 14:49:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.35,
#    'low': 0.3,
#    'open': 0.35,
#    'open_interest': 16528720,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 268645},
#   {'close': 0.3,
#    'datetime': '2026-04-28 14:50:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.35,
#    'low': 0.3,
#    'open': 0.3,
#    'open_interest': 16072810,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 524680},
#   {'close': 0.3,
#    'datetime': '2026-04-28 14:51:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.35,
#    'low': 0.3,
#    'open': 0.3,
#    'open_interest': 16072810,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 856895},
#   {'close': 0.25,
#    'datetime': '2026-04-28 14:52:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.35,
#    'low': 0.25,
#    'open': 0.3,
#    'open_interest': 16072810,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 1524900},
#   {'close': 0.25,
#    'datetime': '2026-04-28 14:53:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.3,
#    'low': 0.25,
#    'open': 0.25,
#    'open_interest': 16220750,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 415155},
#   {'close': 0.25,
#    'datetime': '2026-04-28 14:54:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.3,
#    'low': 0.25,
#    'open': 0.25,
#    'open_interest': 16220750,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 225420},
#   {'close': 0.3,
#    'datetime': '2026-04-28 14:55:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.3,
#    'low': 0.25,
#    'open': 0.25,
#    'open_interest': 16220750,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 402805},
#   {'close': 0.25,
#    'datetime': '2026-04-28 14:56:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.3,
#    'low': 0.25,
#    'open': 0.3,
#    'open_interest': 15931500,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 1889225},
#   {'close': 0.25,
#    'datetime': '2026-04-28 14:57:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.25,
#    'low': 0.2,
#    'open': 0.25,
#    'open_interest': 15931500,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 514280},
#   {'close': 0.25,
#    'datetime': '2026-04-28 14:58:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.25,
#    'low': 0.2,
#    'open': 0.2,
#    'open_interest': 15931500,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 796250},
#   {'close': 0.25,
#    'datetime': '2026-04-28 14:59:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.25,
#    'low': 0.2,
#    'open': 0.25,
#    'open_interest': 15263365,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 845260},
#   {'close': 0.25,
#    'datetime': '2026-04-28 15:00:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.25,
#    'low': 0.2,
#    'open': 0.25,
#    'open_interest': 15263365,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 1004835},
#   {'close': 0.25,
#    'datetime': '2026-04-28 15:01:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.25,
#    'low': 0.2,
#    'open': 0.25,
#    'open_interest': 15263365,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 1116115},
#   {'close': 0.2,
#    'datetime': '2026-04-28 15:02:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.25,
#    'low': 0.15,
#    'open': 0.2,
#    'open_interest': 15263365,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 2495350},
#   {'close': 0.2,
#    'datetime': '2026-04-28 15:03:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.2,
#    'low': 0.15,
#    'open': 0.15,
#    'open_interest': 14602575,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 1613950},
#   {'close': 0.2,
#    'datetime': '2026-04-28 15:04:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.2,
#    'low': 0.15,
#    'open': 0.2,
#    'open_interest': 14602575,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 1944410},
#   {'close': 0.1,
#    'datetime': '2026-04-28 15:05:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.2,
#    'low': 0.1,
#    'open': 0.15,
#    'open_interest': 14602575,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 1564225},
#   {'close': 0.15,
#    'datetime': '2026-04-28 15:06:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.15,
#    'low': 0.1,
#    'open': 0.15,
#    'open_interest': 13861575,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 432770},
#   {'close': 0.15,
#    'datetime': '2026-04-28 15:07:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.15,
#    'low': 0.1,
#    'open': 0.1,
#    'open_interest': 13861575,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 811265},
#   {'close': 0.1,
#    'datetime': '2026-04-28 15:08:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.15,
#    'low': 0.1,
#    'open': 0.1,
#    'open_interest': 13861575,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 528710},
#   {'close': 0.15,
#    'datetime': '2026-04-28 15:09:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.15,
#    'low': 0.1,
#    'open': 0.1,
#    'open_interest': 13557895,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 529750},
#   {'close': 0.15,
#    'datetime': '2026-04-28 15:10:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.15,
#    'low': 0.1,
#    'open': 0.15,
#    'open_interest': 13557895,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 665405},
#   {'close': 0.15,
#    'datetime': '2026-04-28 15:11:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.15,
#    'low': 0.1,
#    'open': 0.15,
#    'open_interest': 13557895,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 1458080},
#   {'close': 0.05,
#    'datetime': '2026-04-28 15:12:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.15,
#    'low': 0.05,
#    'open': 0.15,
#    'open_interest': 13195065,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 900575},
#   {'close': 0.1,
#    'datetime': '2026-04-28 15:13:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.1,
#    'low': 0.05,
#    'open': 0.1,
#    'open_interest': 13195065,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 796770},
#   {'close': 0.1,
#    'datetime': '2026-04-28 15:14:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.1,
#    'low': 0.05,
#    'open': 0.1,
#    'open_interest': 13195065,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 405080},
#   {'close': 0.05,
#    'datetime': '2026-04-28 15:15:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.1,
#    'low': 0.05,
#    'open': 0.1,
#    'open_interest': 12505025,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 437450},
#   {'close': 0.05,
#    'datetime': '2026-04-28 15:16:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.1,
#    'low': 0.05,
#    'open': 0.1,
#    'open_interest': 12505025,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 400855},
#   {'close': 0.05,
#    'datetime': '2026-04-28 15:17:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.1,
#    'low': 0.05,
#    'open': 0.05,
#    'open_interest': 12505025,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 262925},
#   {'close': 0.1,
#    'datetime': '2026-04-28 15:18:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.1,
#    'low': 0.05,
#    'open': 0.05,
#    'open_interest': 12131600,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 256555},
#   {'close': 0.1,
#    'datetime': '2026-04-28 15:19:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.1,
#    'low': 0.05,
#    'open': 0.05,
#    'open_interest': 12131600,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 390000},
#   {'close': 0.05,
#    'datetime': '2026-04-28 15:20:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.1,
#    'low': 0.05,
#    'open': 0.1,
#    'open_interest': 12131600,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 632450},
#   {'close': 0.05,
#    'datetime': '2026-04-28 15:21:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.1,
#    'low': 0.05,
#    'open': 0.1,
#    'open_interest': 11832470,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 350025},
#   {'close': 0.1,
#    'datetime': '2026-04-28 15:22:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.1,
#    'low': 0.05,
#    'open': 0.1,
#    'open_interest': 11832470,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 1490515},
#   {'close': 0.05,
#    'datetime': '2026-04-28 15:23:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.1,
#    'low': 0.05,
#    'open': 0.05,
#    'open_interest': 11832470,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 805155},
#   {'close': 0.1,
#    'datetime': '2026-04-28 15:24:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.1,
#    'low': 0.05,
#    'open': 0.1,
#    'open_interest': 10671115,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 316355},
#   {'close': 0.05,
#    'datetime': '2026-04-28 15:25:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.1,
#    'low': 0.05,
#    'open': 0.1,
#    'open_interest': 10671115,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 666510},
#   {'close': 0.1,
#    'datetime': '2026-04-28 15:26:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.1,
#    'low': 0.05,
#    'open': 0.05,
#    'open_interest': 10671115,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 998140},
#   {'close': 0.05,
#    'datetime': '2026-04-28 15:27:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.1,
#    'low': 0.05,
#    'open': 0.05,
#    'open_interest': 9705020,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 203125},
#   {'close': 0.05,
#    'datetime': '2026-04-28 15:28:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.1,
#    'low': 0.05,
#    'open': 0.05,
#    'open_interest': 9705020,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 262210},
#   {'close': 0.05,
#    'datetime': '2026-04-28 15:29:00',
#    'exchange_code': 'NFO',
#    'expiry_date': '28-APR-2026',
#    'high': 0.05,
#    'low': 0.05,
#    'open': 0.05,
#    'open_interest': 9705020,
#    'product_type': 'Options',
#    'right': 'Call',
#    'stock_code': 'NIFTY',
#    'strike_price': 24200.0,
#    'volume': 111085}]}

# %%
data.keys(),len(data['Success'])
# Out:
# (dict_keys(['Error', 'Status', 'Success']), 1000)

# %%
data
# Out:
# {'Error': None,
#  'Status': 200,
#  'Success': [{'close': 1342.4,
#    'datetime': '2026-04-23 15:11:42',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.4,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 93},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:11:43',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.4,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 112},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:11:44',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.3,
#    'open': 1342.3,
#    'stock_code': 'RELIND',
#    'volume': 58},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:11:45',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.2,
#    'open': 1342.2,
#    'stock_code': 'RELIND',
#    'volume': 189},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:11:46',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.4,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 299},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:11:47',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.3,
#    'open': 1342.3,
#    'stock_code': 'RELIND',
#    'volume': 95},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:11:48',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.4,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 245},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:11:49',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.3,
#    'open': 1342.3,
#    'stock_code': 'RELIND',
#    'volume': 34},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:11:50',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.4,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1342.3,
#    'datetime': '2026-04-23 15:11:51',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.3,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 79},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:11:52',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.4,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 111},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:11:53',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.4,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 419},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:11:54',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.4,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 516},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:11:55',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.4,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 166},
#   {'close': 1342.3,
#    'datetime': '2026-04-23 15:11:56',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.3,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 213},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:11:57',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.4,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 239},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:11:58',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.4,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 110},
#   {'close': 1342.3,
#    'datetime': '2026-04-23 15:11:59',
#    'exchange_code': 'NSE',
#    'high': 1342.3,
#    'low': 1342.3,
#    'open': 1342.3,
#    'stock_code': 'RELIND',
#    'volume': 666},
#   {'close': 1342.3,
#    'datetime': '2026-04-23 15:12:00',
#    'exchange_code': 'NSE',
#    'high': 1342.3,
#    'low': 1342.3,
#    'open': 1342.3,
#    'stock_code': 'RELIND',
#    'volume': 4042},
#   {'close': 1342.3,
#    'datetime': '2026-04-23 15:12:01',
#    'exchange_code': 'NSE',
#    'high': 1342.3,
#    'low': 1342.3,
#    'open': 1342.3,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1342.3,
#    'datetime': '2026-04-23 15:12:02',
#    'exchange_code': 'NSE',
#    'high': 1342.3,
#    'low': 1342.3,
#    'open': 1342.3,
#    'stock_code': 'RELIND',
#    'volume': 506},
#   {'close': 1342.2,
#    'datetime': '2026-04-23 15:12:03',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1342.2,
#    'open': 1342.2,
#    'stock_code': 'RELIND',
#    'volume': 3107},
#   {'close': 1342.3,
#    'datetime': '2026-04-23 15:12:04',
#    'exchange_code': 'NSE',
#    'high': 1342.3,
#    'low': 1342.3,
#    'open': 1342.3,
#    'stock_code': 'RELIND',
#    'volume': 675},
#   {'close': 1342.2,
#    'datetime': '2026-04-23 15:12:05',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1342.2,
#    'open': 1342.2,
#    'stock_code': 'RELIND',
#    'volume': 676},
#   {'close': 1342.3,
#    'datetime': '2026-04-23 15:12:06',
#    'exchange_code': 'NSE',
#    'high': 1342.3,
#    'low': 1342.3,
#    'open': 1342.3,
#    'stock_code': 'RELIND',
#    'volume': 51},
#   {'close': 1342.2,
#    'datetime': '2026-04-23 15:12:07',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1342.2,
#    'open': 1342.2,
#    'stock_code': 'RELIND',
#    'volume': 44},
#   {'close': 1342.2,
#    'datetime': '2026-04-23 15:12:08',
#    'exchange_code': 'NSE',
#    'high': 1342.3,
#    'low': 1342.2,
#    'open': 1342.3,
#    'stock_code': 'RELIND',
#    'volume': 253},
#   {'close': 1342.2,
#    'datetime': '2026-04-23 15:12:09',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1342.2,
#    'open': 1342.2,
#    'stock_code': 'RELIND',
#    'volume': 2439},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:12:10',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.4,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 632},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:12:11',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.4,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 51},
#   {'close': 1342.3,
#    'datetime': '2026-04-23 15:12:12',
#    'exchange_code': 'NSE',
#    'high': 1342.3,
#    'low': 1342.3,
#    'open': 1342.3,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1342.3,
#    'datetime': '2026-04-23 15:12:13',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.3,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 19},
#   {'close': 1342.3,
#    'datetime': '2026-04-23 15:12:14',
#    'exchange_code': 'NSE',
#    'high': 1342.3,
#    'low': 1342.3,
#    'open': 1342.3,
#    'stock_code': 'RELIND',
#    'volume': 415},
#   {'close': 1342.3,
#    'datetime': '2026-04-23 15:12:15',
#    'exchange_code': 'NSE',
#    'high': 1342.3,
#    'low': 1342.3,
#    'open': 1342.3,
#    'stock_code': 'RELIND',
#    'volume': 141},
#   {'close': 1342.3,
#    'datetime': '2026-04-23 15:12:16',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.3,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 292},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:12:17',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.4,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 190},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:12:18',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.4,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 534},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:12:19',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.4,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 64},
#   {'close': 1342.3,
#    'datetime': '2026-04-23 15:12:20',
#    'exchange_code': 'NSE',
#    'high': 1342.3,
#    'low': 1342.3,
#    'open': 1342.3,
#    'stock_code': 'RELIND',
#    'volume': 1798},
#   {'close': 1342.3,
#    'datetime': '2026-04-23 15:12:21',
#    'exchange_code': 'NSE',
#    'high': 1342.3,
#    'low': 1342.3,
#    'open': 1342.3,
#    'stock_code': 'RELIND',
#    'volume': 377},
#   {'close': 1342.3,
#    'datetime': '2026-04-23 15:12:22',
#    'exchange_code': 'NSE',
#    'high': 1342.3,
#    'low': 1342.3,
#    'open': 1342.3,
#    'stock_code': 'RELIND',
#    'volume': 5272},
#   {'close': 1342.1,
#    'datetime': '2026-04-23 15:12:23',
#    'exchange_code': 'NSE',
#    'high': 1342.1,
#    'low': 1342.1,
#    'open': 1342.1,
#    'stock_code': 'RELIND',
#    'volume': 4912},
#   {'close': 1342.3,
#    'datetime': '2026-04-23 15:12:24',
#    'exchange_code': 'NSE',
#    'high': 1342.3,
#    'low': 1342.3,
#    'open': 1342.3,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1342.3,
#    'datetime': '2026-04-23 15:12:25',
#    'exchange_code': 'NSE',
#    'high': 1342.3,
#    'low': 1342.3,
#    'open': 1342.3,
#    'stock_code': 'RELIND',
#    'volume': 10265},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:12:26',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 5765},
#   {'close': 1342.2,
#    'datetime': '2026-04-23 15:12:27',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 4772},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:12:28',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 4871},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:12:29',
#    'exchange_code': 'NSE',
#    'high': 1342.1,
#    'low': 1342.0,
#    'open': 1342.1,
#    'stock_code': 'RELIND',
#    'volume': 5000},
#   {'close': 1341.6,
#    'datetime': '2026-04-23 15:12:30',
#    'exchange_code': 'NSE',
#    'high': 1341.7,
#    'low': 1341.6,
#    'open': 1341.7,
#    'stock_code': 'RELIND',
#    'volume': 9519},
#   {'close': 1341.7,
#    'datetime': '2026-04-23 15:12:31',
#    'exchange_code': 'NSE',
#    'high': 1341.7,
#    'low': 1341.7,
#    'open': 1341.7,
#    'stock_code': 'RELIND',
#    'volume': 8068},
#   {'close': 1341.7,
#    'datetime': '2026-04-23 15:12:32',
#    'exchange_code': 'NSE',
#    'high': 1341.7,
#    'low': 1341.5,
#    'open': 1341.5,
#    'stock_code': 'RELIND',
#    'volume': 5887},
#   {'close': 1341.3,
#    'datetime': '2026-04-23 15:12:33',
#    'exchange_code': 'NSE',
#    'high': 1341.3,
#    'low': 1341.3,
#    'open': 1341.3,
#    'stock_code': 'RELIND',
#    'volume': 4755},
#   {'close': 1341.1,
#    'datetime': '2026-04-23 15:12:34',
#    'exchange_code': 'NSE',
#    'high': 1341.1,
#    'low': 1341.1,
#    'open': 1341.1,
#    'stock_code': 'RELIND',
#    'volume': 5043},
#   {'close': 1341.6,
#    'datetime': '2026-04-23 15:12:35',
#    'exchange_code': 'NSE',
#    'high': 1341.7,
#    'low': 1341.6,
#    'open': 1341.7,
#    'stock_code': 'RELIND',
#    'volume': 11525},
#   {'close': 1341.5,
#    'datetime': '2026-04-23 15:12:36',
#    'exchange_code': 'NSE',
#    'high': 1341.5,
#    'low': 1341.5,
#    'open': 1341.5,
#    'stock_code': 'RELIND',
#    'volume': 4989},
#   {'close': 1341.5,
#    'datetime': '2026-04-23 15:12:37',
#    'exchange_code': 'NSE',
#    'high': 1341.5,
#    'low': 1341.5,
#    'open': 1341.5,
#    'stock_code': 'RELIND',
#    'volume': 14342},
#   {'close': 1341.4,
#    'datetime': '2026-04-23 15:12:38',
#    'exchange_code': 'NSE',
#    'high': 1341.4,
#    'low': 1341.4,
#    'open': 1341.4,
#    'stock_code': 'RELIND',
#    'volume': 4772},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:12:39',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 6373},
#   {'close': 1341.5,
#    'datetime': '2026-04-23 15:12:40',
#    'exchange_code': 'NSE',
#    'high': 1341.5,
#    'low': 1341.2,
#    'open': 1341.2,
#    'stock_code': 'RELIND',
#    'volume': 7424},
#   {'close': 1341.5,
#    'datetime': '2026-04-23 15:12:41',
#    'exchange_code': 'NSE',
#    'high': 1341.5,
#    'low': 1341.4,
#    'open': 1341.4,
#    'stock_code': 'RELIND',
#    'volume': 4955},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:12:42',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 6416},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:12:43',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 809},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:12:44',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1340.9,
#    'datetime': '2026-04-23 15:12:45',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1340.9,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 124},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:12:46',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 612},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:12:47',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 827},
#   {'close': 1340.9,
#    'datetime': '2026-04-23 15:12:48',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1340.9,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 26},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:12:49',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1340.9,
#    'open': 1340.9,
#    'stock_code': 'RELIND',
#    'volume': 2692},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:12:50',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 1920},
#   {'close': 1340.9,
#    'datetime': '2026-04-23 15:12:51',
#    'exchange_code': 'NSE',
#    'high': 1340.9,
#    'low': 1340.9,
#    'open': 1340.9,
#    'stock_code': 'RELIND',
#    'volume': 736},
#   {'close': 1340.9,
#    'datetime': '2026-04-23 15:12:52',
#    'exchange_code': 'NSE',
#    'high': 1340.9,
#    'low': 1340.9,
#    'open': 1340.9,
#    'stock_code': 'RELIND',
#    'volume': 2037},
#   {'close': 1340.9,
#    'datetime': '2026-04-23 15:12:53',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1340.9,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 137},
#   {'close': 1341.1,
#    'datetime': '2026-04-23 15:12:54',
#    'exchange_code': 'NSE',
#    'high': 1341.1,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 1033},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:12:55',
#    'exchange_code': 'NSE',
#    'high': 1341.1,
#    'low': 1341.0,
#    'open': 1341.1,
#    'stock_code': 'RELIND',
#    'volume': 554},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:12:56',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:12:57',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 14},
#   {'close': 1341.1,
#    'datetime': '2026-04-23 15:12:58',
#    'exchange_code': 'NSE',
#    'high': 1341.1,
#    'low': 1341.1,
#    'open': 1341.1,
#    'stock_code': 'RELIND',
#    'volume': 1466},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:12:59',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 830},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:13:00',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 8390},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:13:01',
#    'exchange_code': 'NSE',
#    'high': 1341.2,
#    'low': 1341.0,
#    'open': 1341.2,
#    'stock_code': 'RELIND',
#    'volume': 1751},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:13:02',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 4081},
#   {'close': 1340.9,
#    'datetime': '2026-04-23 15:13:03',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1340.9,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 82},
#   {'close': 1340.9,
#    'datetime': '2026-04-23 15:13:04',
#    'exchange_code': 'NSE',
#    'high': 1340.9,
#    'low': 1340.9,
#    'open': 1340.9,
#    'stock_code': 'RELIND',
#    'volume': 38},
#   {'close': 1340.9,
#    'datetime': '2026-04-23 15:13:05',
#    'exchange_code': 'NSE',
#    'high': 1340.9,
#    'low': 1340.9,
#    'open': 1340.9,
#    'stock_code': 'RELIND',
#    'volume': 660},
#   {'close': 1340.9,
#    'datetime': '2026-04-23 15:13:06',
#    'exchange_code': 'NSE',
#    'high': 1340.9,
#    'low': 1340.9,
#    'open': 1340.9,
#    'stock_code': 'RELIND',
#    'volume': 4},
#   {'close': 1340.9,
#    'datetime': '2026-04-23 15:13:07',
#    'exchange_code': 'NSE',
#    'high': 1340.9,
#    'low': 1340.9,
#    'open': 1340.9,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1340.9,
#    'datetime': '2026-04-23 15:13:08',
#    'exchange_code': 'NSE',
#    'high': 1340.9,
#    'low': 1340.9,
#    'open': 1340.9,
#    'stock_code': 'RELIND',
#    'volume': 377},
#   {'close': 1340.8,
#    'datetime': '2026-04-23 15:13:09',
#    'exchange_code': 'NSE',
#    'high': 1340.8,
#    'low': 1340.8,
#    'open': 1340.8,
#    'stock_code': 'RELIND',
#    'volume': 537},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:13:10',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1340.9,
#    'open': 1340.9,
#    'stock_code': 'RELIND',
#    'volume': 528},
#   {'close': 1340.9,
#    'datetime': '2026-04-23 15:13:11',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1340.9,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 89},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:13:12',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 28},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:13:13',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 105},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:13:14',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 2546},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:13:15',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 4608},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:13:16',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 1884},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:13:17',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 772},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:13:18',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 1302},
#   {'close': 1340.9,
#    'datetime': '2026-04-23 15:13:19',
#    'exchange_code': 'NSE',
#    'high': 1340.9,
#    'low': 1340.9,
#    'open': 1340.9,
#    'stock_code': 'RELIND',
#    'volume': 351},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:13:20',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1340.9,
#    'open': 1340.9,
#    'stock_code': 'RELIND',
#    'volume': 3611},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:13:21',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 98},
#   {'close': 1341.1,
#    'datetime': '2026-04-23 15:13:22',
#    'exchange_code': 'NSE',
#    'high': 1341.1,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 911},
#   {'close': 1341.1,
#    'datetime': '2026-04-23 15:13:23',
#    'exchange_code': 'NSE',
#    'high': 1341.1,
#    'low': 1341.1,
#    'open': 1341.1,
#    'stock_code': 'RELIND',
#    'volume': 1561},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:13:24',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1341.2,
#    'datetime': '2026-04-23 15:13:25',
#    'exchange_code': 'NSE',
#    'high': 1341.2,
#    'low': 1341.2,
#    'open': 1341.2,
#    'stock_code': 'RELIND',
#    'volume': 1353},
#   {'close': 1341.0,
#    'datetime': '2026-04-23 15:13:26',
#    'exchange_code': 'NSE',
#    'high': 1341.0,
#    'low': 1341.0,
#    'open': 1341.0,
#    'stock_code': 'RELIND',
#    'volume': 2744},
#   {'close': 1341.1,
#    'datetime': '2026-04-23 15:13:27',
#    'exchange_code': 'NSE',
#    'high': 1341.1,
#    'low': 1341.1,
#    'open': 1341.1,
#    'stock_code': 'RELIND',
#    'volume': 81},
#   {'close': 1341.2,
#    'datetime': '2026-04-23 15:13:28',
#    'exchange_code': 'NSE',
#    'high': 1341.2,
#    'low': 1341.2,
#    'open': 1341.2,
#    'stock_code': 'RELIND',
#    'volume': 519},
#   {'close': 1341.2,
#    'datetime': '2026-04-23 15:13:29',
#    'exchange_code': 'NSE',
#    'high': 1341.2,
#    'low': 1341.2,
#    'open': 1341.2,
#    'stock_code': 'RELIND',
#    'volume': 252},
#   {'close': 1341.1,
#    'datetime': '2026-04-23 15:13:30',
#    'exchange_code': 'NSE',
#    'high': 1341.1,
#    'low': 1341.1,
#    'open': 1341.1,
#    'stock_code': 'RELIND',
#    'volume': 461},
#   {'close': 1341.2,
#    'datetime': '2026-04-23 15:13:31',
#    'exchange_code': 'NSE',
#    'high': 1341.2,
#    'low': 1341.2,
#    'open': 1341.2,
#    'stock_code': 'RELIND',
#    'volume': 203},
#   {'close': 1341.3,
#    'datetime': '2026-04-23 15:13:32',
#    'exchange_code': 'NSE',
#    'high': 1341.3,
#    'low': 1341.3,
#    'open': 1341.3,
#    'stock_code': 'RELIND',
#    'volume': 2752},
#   {'close': 1341.6,
#    'datetime': '2026-04-23 15:13:33',
#    'exchange_code': 'NSE',
#    'high': 1341.6,
#    'low': 1341.3,
#    'open': 1341.3,
#    'stock_code': 'RELIND',
#    'volume': 1652},
#   {'close': 1341.5,
#    'datetime': '2026-04-23 15:13:34',
#    'exchange_code': 'NSE',
#    'high': 1341.5,
#    'low': 1341.5,
#    'open': 1341.5,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1341.4,
#    'datetime': '2026-04-23 15:13:35',
#    'exchange_code': 'NSE',
#    'high': 1341.6,
#    'low': 1341.4,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 2079},
#   {'close': 1341.4,
#    'datetime': '2026-04-23 15:13:36',
#    'exchange_code': 'NSE',
#    'high': 1341.4,
#    'low': 1341.4,
#    'open': 1341.4,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1341.6,
#    'datetime': '2026-04-23 15:13:37',
#    'exchange_code': 'NSE',
#    'high': 1341.9,
#    'low': 1341.6,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 9201},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:13:38',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 4751},
#   {'close': 1341.9,
#    'datetime': '2026-04-23 15:13:39',
#    'exchange_code': 'NSE',
#    'high': 1341.9,
#    'low': 1341.9,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 6528},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:13:40',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 7945},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:13:41',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 5047},
#   {'close': 1341.7,
#    'datetime': '2026-04-23 15:13:42',
#    'exchange_code': 'NSE',
#    'high': 1341.7,
#    'low': 1341.7,
#    'open': 1341.7,
#    'stock_code': 'RELIND',
#    'volume': 4768},
#   {'close': 1341.6,
#    'datetime': '2026-04-23 15:13:43',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.6,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 4800},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:13:44',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1341.6,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 5719},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:13:45',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.6,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 4820},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:13:46',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 5210},
#   {'close': 1341.7,
#    'datetime': '2026-04-23 15:13:47',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.7,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 9157},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:13:48',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:13:49',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 4758},
#   {'close': 1342.1,
#    'datetime': '2026-04-23 15:13:50',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.1,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 4751},
#   {'close': 1342.5,
#    'datetime': '2026-04-23 15:13:51',
#    'exchange_code': 'NSE',
#    'high': 1342.5,
#    'low': 1342.5,
#    'open': 1342.5,
#    'stock_code': 'RELIND',
#    'volume': 4951},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:13:52',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 5705},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:13:53',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 6423},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:13:54',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1341.8,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 5144},
#   {'close': 1342.3,
#    'datetime': '2026-04-23 15:13:55',
#    'exchange_code': 'NSE',
#    'high': 1342.3,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 6623},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:13:56',
#    'exchange_code': 'NSE',
#    'high': 1342.1,
#    'low': 1341.8,
#    'open': 1342.1,
#    'stock_code': 'RELIND',
#    'volume': 8386},
#   {'close': 1341.7,
#    'datetime': '2026-04-23 15:13:57',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1341.7,
#    'open': 1342.2,
#    'stock_code': 'RELIND',
#    'volume': 2598},
#   {'close': 1341.7,
#    'datetime': '2026-04-23 15:13:58',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1341.7,
#    'open': 1342.2,
#    'stock_code': 'RELIND',
#    'volume': 991},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:13:59',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.6,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 1653},
#   {'close': 1341.7,
#    'datetime': '2026-04-23 15:14:00',
#    'exchange_code': 'NSE',
#    'high': 1341.7,
#    'low': 1341.7,
#    'open': 1341.7,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:14:01',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.7,
#    'open': 1341.7,
#    'stock_code': 'RELIND',
#    'volume': 2852},
#   {'close': 1341.6,
#    'datetime': '2026-04-23 15:14:02',
#    'exchange_code': 'NSE',
#    'high': 1341.6,
#    'low': 1341.6,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 2580},
#   {'close': 1341.4,
#    'datetime': '2026-04-23 15:14:03',
#    'exchange_code': 'NSE',
#    'high': 1341.6,
#    'low': 1341.4,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 5094},
#   {'close': 1341.4,
#    'datetime': '2026-04-23 15:14:04',
#    'exchange_code': 'NSE',
#    'high': 1341.6,
#    'low': 1341.4,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 1005},
#   {'close': 1341.4,
#    'datetime': '2026-04-23 15:14:05',
#    'exchange_code': 'NSE',
#    'high': 1341.6,
#    'low': 1341.4,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 1026},
#   {'close': 1341.6,
#    'datetime': '2026-04-23 15:14:06',
#    'exchange_code': 'NSE',
#    'high': 1341.6,
#    'low': 1341.6,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 952},
#   {'close': 1341.7,
#    'datetime': '2026-04-23 15:14:07',
#    'exchange_code': 'NSE',
#    'high': 1341.7,
#    'low': 1341.7,
#    'open': 1341.7,
#    'stock_code': 'RELIND',
#    'volume': 1470},
#   {'close': 1341.5,
#    'datetime': '2026-04-23 15:14:08',
#    'exchange_code': 'NSE',
#    'high': 1341.6,
#    'low': 1341.5,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 2151},
#   {'close': 1342.1,
#    'datetime': '2026-04-23 15:14:09',
#    'exchange_code': 'NSE',
#    'high': 1342.1,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 1577},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:14:10',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.6,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 986},
#   {'close': 1341.6,
#    'datetime': '2026-04-23 15:14:11',
#    'exchange_code': 'NSE',
#    'high': 1341.6,
#    'low': 1341.6,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 1030},
#   {'close': 1342.1,
#    'datetime': '2026-04-23 15:14:12',
#    'exchange_code': 'NSE',
#    'high': 1342.1,
#    'low': 1341.7,
#    'open': 1341.7,
#    'stock_code': 'RELIND',
#    'volume': 2391},
#   {'close': 1341.6,
#    'datetime': '2026-04-23 15:14:13',
#    'exchange_code': 'NSE',
#    'high': 1341.6,
#    'low': 1341.6,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:14:14',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.6,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 1099},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:14:15',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 1288},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:14:16',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 1531},
#   {'close': 1341.6,
#    'datetime': '2026-04-23 15:14:17',
#    'exchange_code': 'NSE',
#    'high': 1341.6,
#    'low': 1341.6,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 1219},
#   {'close': 1342.1,
#    'datetime': '2026-04-23 15:14:18',
#    'exchange_code': 'NSE',
#    'high': 1342.1,
#    'low': 1342.1,
#    'open': 1342.1,
#    'stock_code': 'RELIND',
#    'volume': 1715},
#   {'close': 1342.2,
#    'datetime': '2026-04-23 15:14:19',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1341.6,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 2157},
#   {'close': 1342.1,
#    'datetime': '2026-04-23 15:14:20',
#    'exchange_code': 'NSE',
#    'high': 1342.1,
#    'low': 1341.6,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 1480},
#   {'close': 1341.5,
#    'datetime': '2026-04-23 15:14:21',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.5,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 1250},
#   {'close': 1341.5,
#    'datetime': '2026-04-23 15:14:22',
#    'exchange_code': 'NSE',
#    'high': 1342.1,
#    'low': 1341.5,
#    'open': 1342.1,
#    'stock_code': 'RELIND',
#    'volume': 964},
#   {'close': 1342.1,
#    'datetime': '2026-04-23 15:14:23',
#    'exchange_code': 'NSE',
#    'high': 1342.1,
#    'low': 1342.1,
#    'open': 1342.1,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:14:24',
#    'exchange_code': 'NSE',
#    'high': 1341.9,
#    'low': 1341.8,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 15445},
#   {'close': 1341.9,
#    'datetime': '2026-04-23 15:14:25',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1341.9,
#    'open': 1342.2,
#    'stock_code': 'RELIND',
#    'volume': 1140},
#   {'close': 1342.2,
#    'datetime': '2026-04-23 15:14:26',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1342.2,
#    'open': 1342.2,
#    'stock_code': 'RELIND',
#    'volume': 1345},
#   {'close': 1342.2,
#    'datetime': '2026-04-23 15:14:27',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1342.2,
#    'open': 1342.2,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1342.1,
#    'datetime': '2026-04-23 15:14:28',
#    'exchange_code': 'NSE',
#    'high': 1342.1,
#    'low': 1341.7,
#    'open': 1341.7,
#    'stock_code': 'RELIND',
#    'volume': 250},
#   {'close': 1342.1,
#    'datetime': '2026-04-23 15:14:29',
#    'exchange_code': 'NSE',
#    'high': 1342.1,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 1315},
#   {'close': 1342.1,
#    'datetime': '2026-04-23 15:14:30',
#    'exchange_code': 'NSE',
#    'high': 1342.1,
#    'low': 1342.1,
#    'open': 1342.1,
#    'stock_code': 'RELIND',
#    'volume': 154},
#   {'close': 1342.2,
#    'datetime': '2026-04-23 15:14:31',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 1578},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:14:32',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 287},
#   {'close': 1342.2,
#    'datetime': '2026-04-23 15:14:33',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1342.2,
#    'open': 1342.2,
#    'stock_code': 'RELIND',
#    'volume': 104},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:14:34',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 1473},
#   {'close': 1341.6,
#    'datetime': '2026-04-23 15:14:35',
#    'exchange_code': 'NSE',
#    'high': 1341.6,
#    'low': 1341.6,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 1597},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:14:36',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 526},
#   {'close': 1341.6,
#    'datetime': '2026-04-23 15:14:37',
#    'exchange_code': 'NSE',
#    'high': 1341.6,
#    'low': 1341.6,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 151},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:14:38',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 131},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:14:39',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1341.4,
#    'datetime': '2026-04-23 15:14:40',
#    'exchange_code': 'NSE',
#    'high': 1341.9,
#    'low': 1341.4,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 1230},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:14:41',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 7609},
#   {'close': 1341.7,
#    'datetime': '2026-04-23 15:14:42',
#    'exchange_code': 'NSE',
#    'high': 1341.7,
#    'low': 1341.7,
#    'open': 1341.7,
#    'stock_code': 'RELIND',
#    'volume': 39},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:14:43',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.7,
#    'open': 1341.7,
#    'stock_code': 'RELIND',
#    'volume': 15},
#   {'close': 1341.6,
#    'datetime': '2026-04-23 15:14:44',
#    'exchange_code': 'NSE',
#    'high': 1341.6,
#    'low': 1341.6,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 845},
#   {'close': 1341.6,
#    'datetime': '2026-04-23 15:14:45',
#    'exchange_code': 'NSE',
#    'high': 1341.6,
#    'low': 1341.6,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 1138},
#   {'close': 1341.6,
#    'datetime': '2026-04-23 15:14:46',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.6,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 245},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:14:47',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 2110},
#   {'close': 1341.9,
#    'datetime': '2026-04-23 15:14:48',
#    'exchange_code': 'NSE',
#    'high': 1341.9,
#    'low': 1341.9,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 1071},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:14:49',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 293},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:14:50',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 1254},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:14:51',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1341.7,
#    'datetime': '2026-04-23 15:14:52',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.7,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 147},
#   {'close': 1341.7,
#    'datetime': '2026-04-23 15:14:53',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.7,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 528},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:14:54',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 186},
#   {'close': 1341.7,
#    'datetime': '2026-04-23 15:14:55',
#    'exchange_code': 'NSE',
#    'high': 1341.9,
#    'low': 1341.7,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 584},
#   {'close': 1341.9,
#    'datetime': '2026-04-23 15:14:56',
#    'exchange_code': 'NSE',
#    'high': 1341.9,
#    'low': 1341.9,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 82},
#   {'close': 1341.9,
#    'datetime': '2026-04-23 15:14:57',
#    'exchange_code': 'NSE',
#    'high': 1341.9,
#    'low': 1341.9,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 13},
#   {'close': 1341.9,
#    'datetime': '2026-04-23 15:14:58',
#    'exchange_code': 'NSE',
#    'high': 1341.9,
#    'low': 1341.9,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 964},
#   {'close': 1341.9,
#    'datetime': '2026-04-23 15:14:59',
#    'exchange_code': 'NSE',
#    'high': 1341.9,
#    'low': 1341.9,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 4000},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:15:00',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1341.9,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 8284},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:15:01',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1341.9,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 4838},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:15:02',
#    'exchange_code': 'NSE',
#    'high': 1342.1,
#    'low': 1342.0,
#    'open': 1342.1,
#    'stock_code': 'RELIND',
#    'volume': 4717},
#   {'close': 1343.0,
#    'datetime': '2026-04-23 15:15:03',
#    'exchange_code': 'NSE',
#    'high': 1343.0,
#    'low': 1343.0,
#    'open': 1343.0,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1342.3,
#    'datetime': '2026-04-23 15:15:04',
#    'exchange_code': 'NSE',
#    'high': 1342.3,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 6242},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:15:05',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 7087},
#   {'close': 1341.9,
#    'datetime': '2026-04-23 15:15:06',
#    'exchange_code': 'NSE',
#    'high': 1342.3,
#    'low': 1341.9,
#    'open': 1342.3,
#    'stock_code': 'RELIND',
#    'volume': 8196},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:15:07',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 7347},
#   {'close': 1342.5,
#    'datetime': '2026-04-23 15:15:08',
#    'exchange_code': 'NSE',
#    'high': 1342.5,
#    'low': 1342.3,
#    'open': 1342.3,
#    'stock_code': 'RELIND',
#    'volume': 11112},
#   {'close': 1341.9,
#    'datetime': '2026-04-23 15:15:09',
#    'exchange_code': 'NSE',
#    'high': 1341.9,
#    'low': 1341.9,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 7667},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:15:10',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1341.9,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 6285},
#   {'close': 1342.5,
#    'datetime': '2026-04-23 15:15:11',
#    'exchange_code': 'NSE',
#    'high': 1342.5,
#    'low': 1342.5,
#    'open': 1342.5,
#    'stock_code': 'RELIND',
#    'volume': 4902},
#   {'close': 1341.9,
#    'datetime': '2026-04-23 15:15:12',
#    'exchange_code': 'NSE',
#    'high': 1341.9,
#    'low': 1341.9,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 5297},
#   {'close': 1342.1,
#    'datetime': '2026-04-23 15:15:13',
#    'exchange_code': 'NSE',
#    'high': 1342.1,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 6346},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:15:14',
#    'exchange_code': 'NSE',
#    'high': 1342.6,
#    'low': 1342.0,
#    'open': 1342.6,
#    'stock_code': 'RELIND',
#    'volume': 6333},
#   {'close': 1342.8,
#    'datetime': '2026-04-23 15:15:15',
#    'exchange_code': 'NSE',
#    'high': 1342.8,
#    'low': 1342.8,
#    'open': 1342.8,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1341.9,
#    'datetime': '2026-04-23 15:15:16',
#    'exchange_code': 'NSE',
#    'high': 1342.7,
#    'low': 1341.9,
#    'open': 1342.7,
#    'stock_code': 'RELIND',
#    'volume': 5627},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:15:17',
#    'exchange_code': 'NSE',
#    'high': 1342.9,
#    'low': 1342.0,
#    'open': 1342.9,
#    'stock_code': 'RELIND',
#    'volume': 9748},
#   {'close': 1341.9,
#    'datetime': '2026-04-23 15:15:18',
#    'exchange_code': 'NSE',
#    'high': 1341.9,
#    'low': 1341.9,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 11104},
#   {'close': 1342.5,
#    'datetime': '2026-04-23 15:15:19',
#    'exchange_code': 'NSE',
#    'high': 1342.5,
#    'low': 1341.9,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 13717},
#   {'close': 1341.9,
#    'datetime': '2026-04-23 15:15:20',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1341.9,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 4529},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:15:21',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 2211},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:15:22',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.7,
#    'open': 1341.7,
#    'stock_code': 'RELIND',
#    'volume': 1221},
#   {'close': 1341.6,
#    'datetime': '2026-04-23 15:15:23',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.6,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 2671},
#   {'close': 1342.2,
#    'datetime': '2026-04-23 15:15:24',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1342.2,
#    'open': 1342.2,
#    'stock_code': 'RELIND',
#    'volume': 1102},
#   {'close': 1342.2,
#    'datetime': '2026-04-23 15:15:25',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1341.9,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 2352},
#   {'close': 1342.2,
#    'datetime': '2026-04-23 15:15:26',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1342.2,
#    'open': 1342.2,
#    'stock_code': 'RELIND',
#    'volume': 969},
#   {'close': 1341.9,
#    'datetime': '2026-04-23 15:15:27',
#    'exchange_code': 'NSE',
#    'high': 1341.9,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 1468},
#   {'close': 1341.9,
#    'datetime': '2026-04-23 15:15:28',
#    'exchange_code': 'NSE',
#    'high': 1341.9,
#    'low': 1341.9,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1342.2,
#    'datetime': '2026-04-23 15:15:29',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1341.7,
#    'open': 1341.7,
#    'stock_code': 'RELIND',
#    'volume': 17319},
#   {'close': 1342.2,
#    'datetime': '2026-04-23 15:15:30',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1341.9,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 1447},
#   {'close': 1342.2,
#    'datetime': '2026-04-23 15:15:31',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1342.2,
#    'open': 1342.2,
#    'stock_code': 'RELIND',
#    'volume': 1701},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:15:32',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1341.7,
#    'open': 1341.7,
#    'stock_code': 'RELIND',
#    'volume': 1051},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:15:33',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 1726},
#   {'close': 1342.2,
#    'datetime': '2026-04-23 15:15:34',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1342.2,
#    'open': 1342.2,
#    'stock_code': 'RELIND',
#    'volume': 2337},
#   {'close': 1342.5,
#    'datetime': '2026-04-23 15:15:35',
#    'exchange_code': 'NSE',
#    'high': 1342.5,
#    'low': 1342.4,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 2151},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:15:36',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 1828},
#   {'close': 1342.4,
#    'datetime': '2026-04-23 15:15:37',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1341.6,
#    'open': 1341.6,
#    'stock_code': 'RELIND',
#    'volume': 1815},
#   {'close': 1341.7,
#    'datetime': '2026-04-23 15:15:38',
#    'exchange_code': 'NSE',
#    'high': 1342.4,
#    'low': 1341.7,
#    'open': 1342.4,
#    'stock_code': 'RELIND',
#    'volume': 323},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:15:39',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1341.7,
#    'datetime': '2026-04-23 15:15:40',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.7,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 1692},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:15:41',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1341.7,
#    'open': 1341.7,
#    'stock_code': 'RELIND',
#    'volume': 662},
#   {'close': 1342.2,
#    'datetime': '2026-04-23 15:15:42',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1342.2,
#    'open': 1342.2,
#    'stock_code': 'RELIND',
#    'volume': 128},
#   {'close': 1342.2,
#    'datetime': '2026-04-23 15:15:43',
#    'exchange_code': 'NSE',
#    'high': 1342.2,
#    'low': 1342.2,
#    'open': 1342.2,
#    'stock_code': 'RELIND',
#    'volume': 752},
#   {'close': 1341.9,
#    'datetime': '2026-04-23 15:15:44',
#    'exchange_code': 'NSE',
#    'high': 1341.9,
#    'low': 1341.9,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 23},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:15:45',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 1177},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:15:46',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 277},
#   {'close': 1341.9,
#    'datetime': '2026-04-23 15:15:47',
#    'exchange_code': 'NSE',
#    'high': 1341.9,
#    'low': 1341.9,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 1672},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:15:48',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1341.9,
#    'open': 1341.9,
#    'stock_code': 'RELIND',
#    'volume': 710},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:15:49',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 1834},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:15:50',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 158},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:15:51',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 69},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:15:52',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 202},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:15:53',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 77},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:15:54',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1341.8,
#    'datetime': '2026-04-23 15:15:55',
#    'exchange_code': 'NSE',
#    'high': 1341.8,
#    'low': 1341.8,
#    'open': 1341.8,
#    'stock_code': 'RELIND',
#    'volume': 1690},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:15:56',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 12},
#   {'close': 1342.0,
#    'datetime': '2026-04-23 15:15:57',
#    'exchange_code': 'NSE',
#    'high': 1342.0,
#    'low': 1342.0,
#    'open': 1342.0,
#    'stock_code': 'RELIND',
#    'volume': 7},
# ...
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 8433},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:28:35',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.3,
#    'open': 1344.3,
#    'stock_code': 'RELIND',
#    'volume': 22228},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:28:36',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 3796},
#   {'close': 1344.5,
#    'datetime': '2026-04-23 15:28:37',
#    'exchange_code': 'NSE',
#    'high': 1344.5,
#    'low': 1344.5,
#    'open': 1344.5,
#    'stock_code': 'RELIND',
#    'volume': 2804},
#   {'close': 1343.7,
#    'datetime': '2026-04-23 15:28:38',
#    'exchange_code': 'NSE',
#    'high': 1343.7,
#    'low': 1343.7,
#    'open': 1343.7,
#    'stock_code': 'RELIND',
#    'volume': 1764},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:28:39',
#    'exchange_code': 'NSE',
#    'high': 1344.0,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1344.6,
#    'datetime': '2026-04-23 15:28:40',
#    'exchange_code': 'NSE',
#    'high': 1344.6,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 101},
#   {'close': 1344.6,
#    'datetime': '2026-04-23 15:28:41',
#    'exchange_code': 'NSE',
#    'high': 1344.6,
#    'low': 1344.6,
#    'open': 1344.6,
#    'stock_code': 'RELIND',
#    'volume': 130},
#   {'close': 1344.6,
#    'datetime': '2026-04-23 15:28:42',
#    'exchange_code': 'NSE',
#    'high': 1344.6,
#    'low': 1344.6,
#    'open': 1344.6,
#    'stock_code': 'RELIND',
#    'volume': 54},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:28:43',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 1760},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:28:44',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 55},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:28:45',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 10},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:28:46',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 30},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:28:47',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 37},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:28:48',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 147},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:28:49',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:28:50',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.0,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 5},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:28:51',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 106},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:28:52',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 153},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:28:53',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.0,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 68},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:28:54',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 2647},
#   {'close': 1344.5,
#    'datetime': '2026-04-23 15:28:55',
#    'exchange_code': 'NSE',
#    'high': 1344.5,
#    'low': 1344.5,
#    'open': 1344.5,
#    'stock_code': 'RELIND',
#    'volume': 1518},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:28:56',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 360},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:28:57',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1344.3,
#    'datetime': '2026-04-23 15:28:58',
#    'exchange_code': 'NSE',
#    'high': 1344.3,
#    'low': 1344.3,
#    'open': 1344.3,
#    'stock_code': 'RELIND',
#    'volume': 99},
#   {'close': 1344.3,
#    'datetime': '2026-04-23 15:28:59',
#    'exchange_code': 'NSE',
#    'high': 1344.3,
#    'low': 1344.3,
#    'open': 1344.3,
#    'stock_code': 'RELIND',
#    'volume': 33},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:29:00',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.0,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 580},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:29:01',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 549},
#   {'close': 1344.5,
#    'datetime': '2026-04-23 15:29:02',
#    'exchange_code': 'NSE',
#    'high': 1344.5,
#    'low': 1344.5,
#    'open': 1344.5,
#    'stock_code': 'RELIND',
#    'volume': 1093},
#   {'close': 1344.5,
#    'datetime': '2026-04-23 15:29:03',
#    'exchange_code': 'NSE',
#    'high': 1344.5,
#    'low': 1344.5,
#    'open': 1344.5,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1344.1,
#    'datetime': '2026-04-23 15:29:04',
#    'exchange_code': 'NSE',
#    'high': 1344.1,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 41},
#   {'close': 1344.5,
#    'datetime': '2026-04-23 15:29:05',
#    'exchange_code': 'NSE',
#    'high': 1344.5,
#    'low': 1344.5,
#    'open': 1344.5,
#    'stock_code': 'RELIND',
#    'volume': 132},
#   {'close': 1344.3,
#    'datetime': '2026-04-23 15:29:06',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.3,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 11003},
#   {'close': 1344.3,
#    'datetime': '2026-04-23 15:29:07',
#    'exchange_code': 'NSE',
#    'high': 1344.3,
#    'low': 1344.3,
#    'open': 1344.3,
#    'stock_code': 'RELIND',
#    'volume': 3839},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:29:08',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 246},
#   {'close': 1344.3,
#    'datetime': '2026-04-23 15:29:09',
#    'exchange_code': 'NSE',
#    'high': 1344.5,
#    'low': 1344.3,
#    'open': 1344.5,
#    'stock_code': 'RELIND',
#    'volume': 93},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:29:10',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 71},
#   {'close': 1344.3,
#    'datetime': '2026-04-23 15:29:11',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.3,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 20},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:29:12',
#    'exchange_code': 'NSE',
#    'high': 1344.0,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 4028},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:29:13',
#    'exchange_code': 'NSE',
#    'high': 1344.0,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 534},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:29:14',
#    'exchange_code': 'NSE',
#    'high': 1344.0,
#    'low': 1343.7,
#    'open': 1343.7,
#    'stock_code': 'RELIND',
#    'volume': 1511},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:29:15',
#    'exchange_code': 'NSE',
#    'high': 1344.0,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 53},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:29:16',
#    'exchange_code': 'NSE',
#    'high': 1344.0,
#    'low': 1343.9,
#    'open': 1343.9,
#    'stock_code': 'RELIND',
#    'volume': 10746},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:29:17',
#    'exchange_code': 'NSE',
#    'high': 1344.0,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 17},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:29:18',
#    'exchange_code': 'NSE',
#    'high': 1344.0,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 40},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:29:19',
#    'exchange_code': 'NSE',
#    'high': 1344.0,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 2612},
#   {'close': 1343.9,
#    'datetime': '2026-04-23 15:29:20',
#    'exchange_code': 'NSE',
#    'high': 1343.9,
#    'low': 1343.9,
#    'open': 1343.9,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1343.9,
#    'datetime': '2026-04-23 15:29:21',
#    'exchange_code': 'NSE',
#    'high': 1344.0,
#    'low': 1343.9,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 604},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:29:22',
#    'exchange_code': 'NSE',
#    'high': 1344.0,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 1815},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:29:23',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1343.9,
#    'open': 1343.9,
#    'stock_code': 'RELIND',
#    'volume': 1100},
#   {'close': 1344.5,
#    'datetime': '2026-04-23 15:29:24',
#    'exchange_code': 'NSE',
#    'high': 1344.5,
#    'low': 1343.7,
#    'open': 1343.7,
#    'stock_code': 'RELIND',
#    'volume': 872},
#   {'close': 1344.1,
#    'datetime': '2026-04-23 15:29:25',
#    'exchange_code': 'NSE',
#    'high': 1344.5,
#    'low': 1344.1,
#    'open': 1344.5,
#    'stock_code': 'RELIND',
#    'volume': 125},
#   {'close': 1344.5,
#    'datetime': '2026-04-23 15:29:26',
#    'exchange_code': 'NSE',
#    'high': 1344.5,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 479},
#   {'close': 1344.1,
#    'datetime': '2026-04-23 15:29:27',
#    'exchange_code': 'NSE',
#    'high': 1344.1,
#    'low': 1344.1,
#    'open': 1344.1,
#    'stock_code': 'RELIND',
#    'volume': 56},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:29:28',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 15},
#   {'close': 1344.1,
#    'datetime': '2026-04-23 15:29:29',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.1,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 87},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:29:30',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 474},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:29:31',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 129},
#   {'close': 1344.5,
#    'datetime': '2026-04-23 15:29:32',
#    'exchange_code': 'NSE',
#    'high': 1344.5,
#    'low': 1344.5,
#    'open': 1344.5,
#    'stock_code': 'RELIND',
#    'volume': 249},
#   {'close': 1343.7,
#    'datetime': '2026-04-23 15:29:33',
#    'exchange_code': 'NSE',
#    'high': 1343.7,
#    'low': 1343.7,
#    'open': 1343.7,
#    'stock_code': 'RELIND',
#    'volume': 669},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:29:34',
#    'exchange_code': 'NSE',
#    'high': 1344.0,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:29:35',
#    'exchange_code': 'NSE',
#    'high': 1344.0,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 126},
#   {'close': 1344.1,
#    'datetime': '2026-04-23 15:29:36',
#    'exchange_code': 'NSE',
#    'high': 1344.1,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 222},
#   {'close': 1344.1,
#    'datetime': '2026-04-23 15:29:37',
#    'exchange_code': 'NSE',
#    'high': 1344.1,
#    'low': 1344.1,
#    'open': 1344.1,
#    'stock_code': 'RELIND',
#    'volume': 492},
#   {'close': 1344.1,
#    'datetime': '2026-04-23 15:29:38',
#    'exchange_code': 'NSE',
#    'high': 1344.1,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 7},
#   {'close': 1344.1,
#    'datetime': '2026-04-23 15:29:39',
#    'exchange_code': 'NSE',
#    'high': 1344.1,
#    'low': 1344.1,
#    'open': 1344.1,
#    'stock_code': 'RELIND',
#    'volume': 516},
#   {'close': 1343.8,
#    'datetime': '2026-04-23 15:29:40',
#    'exchange_code': 'NSE',
#    'high': 1343.8,
#    'low': 1343.8,
#    'open': 1343.8,
#    'stock_code': 'RELIND',
#    'volume': 1428},
#   {'close': 1344.5,
#    'datetime': '2026-04-23 15:29:41',
#    'exchange_code': 'NSE',
#    'high': 1344.5,
#    'low': 1344.5,
#    'open': 1344.5,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1344.3,
#    'datetime': '2026-04-23 15:29:42',
#    'exchange_code': 'NSE',
#    'high': 1344.5,
#    'low': 1344.3,
#    'open': 1344.5,
#    'stock_code': 'RELIND',
#    'volume': 302},
#   {'close': 1344.2,
#    'datetime': '2026-04-23 15:29:43',
#    'exchange_code': 'NSE',
#    'high': 1344.3,
#    'low': 1344.2,
#    'open': 1344.3,
#    'stock_code': 'RELIND',
#    'volume': 23},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:29:44',
#    'exchange_code': 'NSE',
#    'high': 1344.2,
#    'low': 1344.0,
#    'open': 1344.2,
#    'stock_code': 'RELIND',
#    'volume': 211},
#   {'close': 1343.0,
#    'datetime': '2026-04-23 15:29:45',
#    'exchange_code': 'NSE',
#    'high': 1343.0,
#    'low': 1343.0,
#    'open': 1343.0,
#    'stock_code': 'RELIND',
#    'volume': 33740},
#   {'close': 1342.9,
#    'datetime': '2026-04-23 15:29:46',
#    'exchange_code': 'NSE',
#    'high': 1343.0,
#    'low': 1342.9,
#    'open': 1343.0,
#    'stock_code': 'RELIND',
#    'volume': 17806},
#   {'close': 1343.9,
#    'datetime': '2026-04-23 15:29:47',
#    'exchange_code': 'NSE',
#    'high': 1343.9,
#    'low': 1343.0,
#    'open': 1343.0,
#    'stock_code': 'RELIND',
#    'volume': 2666},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:29:48',
#    'exchange_code': 'NSE',
#    'high': 1344.0,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 46},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:29:49',
#    'exchange_code': 'NSE',
#    'high': 1344.0,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 250},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:29:50',
#    'exchange_code': 'NSE',
#    'high': 1344.0,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 39},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:29:51',
#    'exchange_code': 'NSE',
#    'high': 1344.0,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 413},
#   {'close': 1343.9,
#    'datetime': '2026-04-23 15:29:52',
#    'exchange_code': 'NSE',
#    'high': 1343.9,
#    'low': 1343.9,
#    'open': 1343.9,
#    'stock_code': 'RELIND',
#    'volume': 11},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:29:53',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 661},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:29:54',
#    'exchange_code': 'NSE',
#    'high': 1344.0,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 48},
#   {'close': 1344.0,
#    'datetime': '2026-04-23 15:29:55',
#    'exchange_code': 'NSE',
#    'high': 1344.0,
#    'low': 1344.0,
#    'open': 1344.0,
#    'stock_code': 'RELIND',
#    'volume': 15},
#   {'close': 1343.0,
#    'datetime': '2026-04-23 15:29:56',
#    'exchange_code': 'NSE',
#    'high': 1343.0,
#    'low': 1343.0,
#    'open': 1343.0,
#    'stock_code': 'RELIND',
#    'volume': 178},
#   {'close': 1343.0,
#    'datetime': '2026-04-23 15:29:57',
#    'exchange_code': 'NSE',
#    'high': 1343.0,
#    'low': 1343.0,
#    'open': 1343.0,
#    'stock_code': 'RELIND',
#    'volume': 0},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:29:58',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 88},
#   {'close': 1344.4,
#    'datetime': '2026-04-23 15:29:59',
#    'exchange_code': 'NSE',
#    'high': 1344.4,
#    'low': 1344.4,
#    'open': 1344.4,
#    'stock_code': 'RELIND',
#    'volume': 0}]}

# %%
from datetime import datetime, timedelta

start = datetime(2026, 1, 1, 9, 15)
end = datetime(2026, 1, 10, 15, 30)

delta = timedelta(minutes=1000)  # for 1-min data (1000 candles)

current = start
all_data = []

while current < end:
    next_time = current + delta
    
    data = breeze.get_historical_data_v2(
        interval="1minute",
        from_date=current.strftime("%Y-%m-%dT%H:%M:%S.000Z"),
        to_date=min(next_time, end).strftime("%Y-%m-%dT%H:%M:%S.000Z"),
        stock_code="RELIND",
        exchange_code="NSE",
        product_type="cash"
    )
    
    all_data.extend(data["Success"])
    current = next_time

# %%
all_data
# Out:
# [{'close': 1577.5,
#   'datetime': '2026-01-01 09:15:00',
#   'exchange_code': 'NSE',
#   'high': 1577.8,
#   'low': 1573.0,
#   'open': 1573.0,
#   'stock_code': 'RELIND',
#   'volume': 121328},
#  {'close': 1578.4,
#   'datetime': '2026-01-01 09:16:00',
#   'exchange_code': 'NSE',
#   'high': 1579.0,
#   'low': 1576.0,
#   'open': 1577.5,
#   'stock_code': 'RELIND',
#   'volume': 90338},
#  {'close': 1576.4,
#   'datetime': '2026-01-01 09:17:00',
#   'exchange_code': 'NSE',
#   'high': 1578.0,
#   'low': 1576.4,
#   'open': 1578.0,
#   'stock_code': 'RELIND',
#   'volume': 22106},
#  {'close': 1576.4,
#   'datetime': '2026-01-01 09:18:00',
#   'exchange_code': 'NSE',
#   'high': 1576.7,
#   'low': 1575.6,
#   'open': 1576.4,
#   'stock_code': 'RELIND',
#   'volume': 20986},
#  {'close': 1575.3,
#   'datetime': '2026-01-01 09:19:00',
#   'exchange_code': 'NSE',
#   'high': 1576.1,
#   'low': 1575.2,
#   'open': 1576.0,
#   'stock_code': 'RELIND',
#   'volume': 16609},
#  {'close': 1575.6,
#   'datetime': '2026-01-01 09:20:00',
#   'exchange_code': 'NSE',
#   'high': 1576.5,
#   'low': 1575.2,
#   'open': 1575.3,
#   'stock_code': 'RELIND',
#   'volume': 16005},
#  {'close': 1577.4,
#   'datetime': '2026-01-01 09:21:00',
#   'exchange_code': 'NSE',
#   'high': 1577.6,
#   'low': 1575.5,
#   'open': 1575.6,
#   'stock_code': 'RELIND',
#   'volume': 11969},
#  {'close': 1577.0,
#   'datetime': '2026-01-01 09:22:00',
#   'exchange_code': 'NSE',
#   'high': 1577.7,
#   'low': 1576.7,
#   'open': 1577.3,
#   'stock_code': 'RELIND',
#   'volume': 10985},
#  {'close': 1577.9,
#   'datetime': '2026-01-01 09:23:00',
#   'exchange_code': 'NSE',
#   'high': 1578.8,
#   'low': 1576.9,
#   'open': 1577.0,
#   'stock_code': 'RELIND',
#   'volume': 20769},
#  {'close': 1579.5,
#   'datetime': '2026-01-01 09:24:00',
#   'exchange_code': 'NSE',
#   'high': 1579.9,
#   'low': 1577.3,
#   'open': 1577.9,
#   'stock_code': 'RELIND',
#   'volume': 28871},
#  {'close': 1582.8,
#   'datetime': '2026-01-01 09:25:00',
#   'exchange_code': 'NSE',
#   'high': 1582.8,
#   'low': 1579.5,
#   'open': 1579.8,
#   'stock_code': 'RELIND',
#   'volume': 54903},
#  {'close': 1581.0,
#   'datetime': '2026-01-01 09:26:00',
#   'exchange_code': 'NSE',
#   'high': 1583.4,
#   'low': 1581.0,
#   'open': 1582.8,
#   'stock_code': 'RELIND',
#   'volume': 32863},
#  {'close': 1583.3,
#   'datetime': '2026-01-01 09:27:00',
#   'exchange_code': 'NSE',
#   'high': 1583.7,
#   'low': 1581.3,
#   'open': 1581.5,
#   'stock_code': 'RELIND',
#   'volume': 26554},
#  {'close': 1587.1,
#   'datetime': '2026-01-01 09:28:00',
#   'exchange_code': 'NSE',
#   'high': 1587.7,
#   'low': 1583.1,
#   'open': 1583.1,
#   'stock_code': 'RELIND',
#   'volume': 104752},
#  {'close': 1588.7,
#   'datetime': '2026-01-01 09:29:00',
#   'exchange_code': 'NSE',
#   'high': 1589.6,
#   'low': 1587.1,
#   'open': 1587.5,
#   'stock_code': 'RELIND',
#   'volume': 70039},
#  {'close': 1590.1,
#   'datetime': '2026-01-01 09:30:00',
#   'exchange_code': 'NSE',
#   'high': 1590.8,
#   'low': 1587.3,
#   'open': 1588.5,
#   'stock_code': 'RELIND',
#   'volume': 95012},
#  {'close': 1589.4,
#   'datetime': '2026-01-01 09:31:00',
#   'exchange_code': 'NSE',
#   'high': 1590.5,
#   'low': 1586.7,
#   'open': 1590.5,
#   'stock_code': 'RELIND',
#   'volume': 70366},
#  {'close': 1589.4,
#   'datetime': '2026-01-01 09:32:00',
#   'exchange_code': 'NSE',
#   'high': 1590.6,
#   'low': 1589.0,
#   'open': 1589.6,
#   'stock_code': 'RELIND',
#   'volume': 45122},
#  {'close': 1588.9,
#   'datetime': '2026-01-01 09:33:00',
#   'exchange_code': 'NSE',
#   'high': 1592.4,
#   'low': 1588.9,
#   'open': 1589.6,
#   'stock_code': 'RELIND',
#   'volume': 80406},
#  {'close': 1588.3,
#   'datetime': '2026-01-01 09:34:00',
#   'exchange_code': 'NSE',
#   'high': 1589.9,
#   'low': 1588.0,
#   'open': 1588.9,
#   'stock_code': 'RELIND',
#   'volume': 27584},
#  {'close': 1589.0,
#   'datetime': '2026-01-01 09:35:00',
#   'exchange_code': 'NSE',
#   'high': 1589.5,
#   'low': 1588.1,
#   'open': 1588.3,
#   'stock_code': 'RELIND',
#   'volume': 9976},
#  {'close': 1589.0,
#   'datetime': '2026-01-01 09:36:00',
#   'exchange_code': 'NSE',
#   'high': 1589.7,
#   'low': 1588.2,
#   'open': 1589.6,
#   'stock_code': 'RELIND',
#   'volume': 10206},
#  {'close': 1589.0,
#   'datetime': '2026-01-01 09:37:00',
#   'exchange_code': 'NSE',
#   'high': 1589.6,
#   'low': 1588.0,
#   'open': 1588.9,
#   'stock_code': 'RELIND',
#   'volume': 14923},
#  {'close': 1587.5,
#   'datetime': '2026-01-01 09:38:00',
#   'exchange_code': 'NSE',
#   'high': 1589.0,
#   'low': 1587.4,
#   'open': 1589.0,
#   'stock_code': 'RELIND',
#   'volume': 7251},
#  {'close': 1588.0,
#   'datetime': '2026-01-01 09:39:00',
#   'exchange_code': 'NSE',
#   'high': 1588.0,
#   'low': 1586.6,
#   'open': 1588.0,
#   'stock_code': 'RELIND',
#   'volume': 18094},
#  {'close': 1587.5,
#   'datetime': '2026-01-01 09:40:00',
#   'exchange_code': 'NSE',
#   'high': 1588.0,
#   'low': 1587.0,
#   'open': 1587.5,
#   'stock_code': 'RELIND',
#   'volume': 8829},
#  {'close': 1586.5,
#   'datetime': '2026-01-01 09:41:00',
#   'exchange_code': 'NSE',
#   'high': 1587.9,
#   'low': 1586.3,
#   'open': 1587.5,
#   'stock_code': 'RELIND',
#   'volume': 8549},
#  {'close': 1586.6,
#   'datetime': '2026-01-01 09:42:00',
#   'exchange_code': 'NSE',
#   'high': 1587.4,
#   'low': 1586.0,
#   'open': 1586.7,
#   'stock_code': 'RELIND',
#   'volume': 12633},
#  {'close': 1586.9,
#   'datetime': '2026-01-01 09:43:00',
#   'exchange_code': 'NSE',
#   'high': 1587.0,
#   'low': 1586.0,
#   'open': 1586.7,
#   'stock_code': 'RELIND',
#   'volume': 9191},
#  {'close': 1586.0,
#   'datetime': '2026-01-01 09:44:00',
#   'exchange_code': 'NSE',
#   'high': 1586.9,
#   'low': 1585.2,
#   'open': 1586.2,
#   'stock_code': 'RELIND',
#   'volume': 15680},
#  {'close': 1584.4,
#   'datetime': '2026-01-01 09:45:00',
#   'exchange_code': 'NSE',
#   'high': 1586.3,
#   'low': 1584.2,
#   'open': 1585.6,
#   'stock_code': 'RELIND',
#   'volume': 22407},
#  {'close': 1584.8,
#   'datetime': '2026-01-01 09:46:00',
#   'exchange_code': 'NSE',
#   'high': 1585.9,
#   'low': 1584.3,
#   'open': 1584.3,
#   'stock_code': 'RELIND',
#   'volume': 12864},
#  {'close': 1584.8,
#   'datetime': '2026-01-01 09:47:00',
#   'exchange_code': 'NSE',
#   'high': 1585.5,
#   'low': 1584.4,
#   'open': 1584.6,
#   'stock_code': 'RELIND',
#   'volume': 8620},
#  {'close': 1584.8,
#   'datetime': '2026-01-01 09:48:00',
#   'exchange_code': 'NSE',
#   'high': 1585.5,
#   'low': 1584.5,
#   'open': 1584.8,
#   'stock_code': 'RELIND',
#   'volume': 7192},
#  {'close': 1584.8,
#   'datetime': '2026-01-01 09:49:00',
#   'exchange_code': 'NSE',
#   'high': 1584.8,
#   'low': 1584.4,
#   'open': 1584.8,
#   'stock_code': 'RELIND',
#   'volume': 4456},
#  {'close': 1584.5,
#   'datetime': '2026-01-01 09:50:00',
#   'exchange_code': 'NSE',
#   'high': 1585.0,
#   'low': 1584.5,
#   'open': 1585.0,
#   'stock_code': 'RELIND',
#   'volume': 6624},
#  {'close': 1584.7,
#   'datetime': '2026-01-01 09:51:00',
#   'exchange_code': 'NSE',
#   'high': 1585.0,
#   'low': 1584.1,
#   'open': 1584.5,
#   'stock_code': 'RELIND',
#   'volume': 13308},
#  {'close': 1584.2,
#   'datetime': '2026-01-01 09:52:00',
#   'exchange_code': 'NSE',
#   'high': 1584.7,
#   'low': 1584.1,
#   'open': 1584.3,
#   'stock_code': 'RELIND',
#   'volume': 7462},
#  {'close': 1584.5,
#   'datetime': '2026-01-01 09:53:00',
#   'exchange_code': 'NSE',
#   'high': 1584.5,
#   'low': 1583.2,
#   'open': 1584.1,
#   'stock_code': 'RELIND',
#   'volume': 31904},
#  {'close': 1583.7,
#   'datetime': '2026-01-01 09:54:00',
#   'exchange_code': 'NSE',
#   'high': 1584.6,
#   'low': 1583.3,
#   'open': 1584.2,
#   'stock_code': 'RELIND',
#   'volume': 7955},
#  {'close': 1585.0,
#   'datetime': '2026-01-01 09:55:00',
#   'exchange_code': 'NSE',
#   'high': 1585.0,
#   'low': 1584.2,
#   'open': 1584.3,
#   'stock_code': 'RELIND',
#   'volume': 8357},
#  {'close': 1585.5,
#   'datetime': '2026-01-01 09:56:00',
#   'exchange_code': 'NSE',
#   'high': 1586.7,
#   'low': 1584.6,
#   'open': 1584.6,
#   'stock_code': 'RELIND',
#   'volume': 25782},
#  {'close': 1585.6,
#   'datetime': '2026-01-01 09:57:00',
#   'exchange_code': 'NSE',
#   'high': 1586.9,
#   'low': 1585.4,
#   'open': 1585.9,
#   'stock_code': 'RELIND',
#   'volume': 19396},
#  {'close': 1584.8,
#   'datetime': '2026-01-01 09:58:00',
#   'exchange_code': 'NSE',
#   'high': 1585.9,
#   'low': 1584.1,
#   'open': 1585.9,
#   'stock_code': 'RELIND',
#   'volume': 8909},
#  {'close': 1583.1,
#   'datetime': '2026-01-01 09:59:00',
#   'exchange_code': 'NSE',
#   'high': 1584.8,
#   'low': 1582.9,
#   'open': 1584.8,
#   'stock_code': 'RELIND',
#   'volume': 18923},
#  {'close': 1583.9,
#   'datetime': '2026-01-01 10:00:00',
#   'exchange_code': 'NSE',
#   'high': 1583.9,
#   'low': 1582.9,
#   'open': 1583.5,
#   'stock_code': 'RELIND',
#   'volume': 2779},
#  {'close': 1583.5,
#   'datetime': '2026-01-01 10:01:00',
#   'exchange_code': 'NSE',
#   'high': 1584.7,
#   'low': 1583.5,
#   'open': 1583.9,
#   'stock_code': 'RELIND',
#   'volume': 13022},
#  {'close': 1584.4,
#   'datetime': '2026-01-01 10:02:00',
#   'exchange_code': 'NSE',
#   'high': 1584.5,
#   'low': 1582.6,
#   'open': 1583.5,
#   'stock_code': 'RELIND',
#   'volume': 13173},
#  {'close': 1584.5,
#   'datetime': '2026-01-01 10:03:00',
#   'exchange_code': 'NSE',
#   'high': 1584.5,
#   'low': 1584.0,
#   'open': 1584.0,
#   'stock_code': 'RELIND',
#   'volume': 2564},
#  {'close': 1585.4,
#   'datetime': '2026-01-01 10:04:00',
#   'exchange_code': 'NSE',
#   'high': 1585.7,
#   'low': 1584.7,
#   'open': 1584.7,
#   'stock_code': 'RELIND',
#   'volume': 15926},
#  {'close': 1585.5,
#   'datetime': '2026-01-01 10:05:00',
#   'exchange_code': 'NSE',
#   'high': 1585.9,
#   'low': 1585.1,
#   'open': 1585.7,
#   'stock_code': 'RELIND',
#   'volume': 8105},
#  {'close': 1586.0,
#   'datetime': '2026-01-01 10:06:00',
#   'exchange_code': 'NSE',
#   'high': 1586.0,
#   'low': 1585.1,
#   'open': 1585.6,
#   'stock_code': 'RELIND',
#   'volume': 6091},
#  {'close': 1587.0,
#   'datetime': '2026-01-01 10:07:00',
#   'exchange_code': 'NSE',
#   'high': 1587.5,
#   'low': 1585.1,
#   'open': 1585.6,
#   'stock_code': 'RELIND',
#   'volume': 40336},
#  {'close': 1586.1,
#   'datetime': '2026-01-01 10:08:00',
#   'exchange_code': 'NSE',
#   'high': 1587.5,
#   'low': 1586.1,
#   'open': 1587.1,
#   'stock_code': 'RELIND',
#   'volume': 46594},
#  {'close': 1585.5,
#   'datetime': '2026-01-01 10:09:00',
#   'exchange_code': 'NSE',
#   'high': 1587.2,
#   'low': 1585.5,
#   'open': 1586.1,
#   'stock_code': 'RELIND',
#   'volume': 22546},
#  {'close': 1585.1,
#   'datetime': '2026-01-01 10:10:00',
#   'exchange_code': 'NSE',
#   'high': 1585.6,
#   'low': 1584.7,
#   'open': 1585.6,
#   'stock_code': 'RELIND',
#   'volume': 4736},
#  {'close': 1583.9,
#   'datetime': '2026-01-01 10:11:00',
#   'exchange_code': 'NSE',
#   'high': 1585.4,
#   'low': 1583.7,
#   'open': 1585.4,
#   'stock_code': 'RELIND',
#   'volume': 6353},
#  {'close': 1583.0,
#   'datetime': '2026-01-01 10:12:00',
#   'exchange_code': 'NSE',
#   'high': 1583.9,
#   'low': 1582.2,
#   'open': 1583.7,
#   'stock_code': 'RELIND',
#   'volume': 16509},
#  {'close': 1582.8,
#   'datetime': '2026-01-01 10:13:00',
#   'exchange_code': 'NSE',
#   'high': 1583.0,
#   'low': 1582.5,
#   'open': 1582.9,
#   'stock_code': 'RELIND',
#   'volume': 4590},
#  {'close': 1582.2,
#   'datetime': '2026-01-01 10:14:00',
#   'exchange_code': 'NSE',
#   'high': 1583.3,
#   'low': 1582.2,
#   'open': 1582.8,
#   'stock_code': 'RELIND',
#   'volume': 5889},
#  {'close': 1582.0,
#   'datetime': '2026-01-01 10:15:00',
#   'exchange_code': 'NSE',
#   'high': 1582.9,
#   'low': 1581.5,
#   'open': 1582.4,
#   'stock_code': 'RELIND',
#   'volume': 9657},
#  {'close': 1582.6,
#   'datetime': '2026-01-01 10:16:00',
#   'exchange_code': 'NSE',
#   'high': 1582.6,
#   'low': 1581.5,
#   'open': 1582.0,
#   'stock_code': 'RELIND',
#   'volume': 6350},
#  {'close': 1581.9,
#   'datetime': '2026-01-01 10:17:00',
#   'exchange_code': 'NSE',
#   'high': 1582.6,
#   'low': 1581.1,
#   'open': 1582.6,
#   'stock_code': 'RELIND',
#   'volume': 13951},
#  {'close': 1581.2,
#   'datetime': '2026-01-01 10:18:00',
#   'exchange_code': 'NSE',
#   'high': 1582.0,
#   'low': 1581.2,
#   'open': 1581.9,
#   'stock_code': 'RELIND',
#   'volume': 5375},
#  {'close': 1580.6,
#   'datetime': '2026-01-01 10:19:00',
#   'exchange_code': 'NSE',
#   'high': 1581.2,
#   'low': 1580.4,
#   'open': 1581.0,
#   'stock_code': 'RELIND',
#   'volume': 18386},
#  {'close': 1580.6,
#   'datetime': '2026-01-01 10:20:00',
#   'exchange_code': 'NSE',
#   'high': 1581.0,
#   'low': 1580.6,
#   'open': 1580.6,
#   'stock_code': 'RELIND',
#   'volume': 5694},
#  {'close': 1580.2,
#   'datetime': '2026-01-01 10:21:00',
#   'exchange_code': 'NSE',
#   'high': 1580.9,
#   'low': 1580.0,
#   'open': 1580.9,
#   'stock_code': 'RELIND',
#   'volume': 16405},
#  {'close': 1579.9,
#   'datetime': '2026-01-01 10:22:00',
#   'exchange_code': 'NSE',
#   'high': 1580.5,
#   'low': 1579.5,
#   'open': 1580.2,
#   'stock_code': 'RELIND',
#   'volume': 14390},
#  {'close': 1580.3,
#   'datetime': '2026-01-01 10:23:00',
#   'exchange_code': 'NSE',
#   'high': 1580.4,
#   'low': 1579.6,
#   'open': 1580.0,
#   'stock_code': 'RELIND',
#   'volume': 5711},
#  {'close': 1581.0,
#   'datetime': '2026-01-01 10:24:00',
#   'exchange_code': 'NSE',
#   'high': 1581.0,
#   'low': 1580.0,
#   'open': 1580.0,
#   'stock_code': 'RELIND',
#   'volume': 7892},
#  {'close': 1581.3,
#   'datetime': '2026-01-01 10:25:00',
#   'exchange_code': 'NSE',
#   'high': 1581.3,
#   'low': 1580.4,
#   'open': 1580.4,
#   'stock_code': 'RELIND',
#   'volume': 3378},
#  {'close': 1581.9,
#   'datetime': '2026-01-01 10:26:00',
#   'exchange_code': 'NSE',
#   'high': 1581.9,
#   'low': 1581.0,
#   'open': 1581.3,
#   'stock_code': 'RELIND',
#   'volume': 7585},
#  {'close': 1581.4,
#   'datetime': '2026-01-01 10:27:00',
#   'exchange_code': 'NSE',
#   'high': 1582.0,
#   'low': 1581.4,
#   'open': 1581.9,
#   'stock_code': 'RELIND',
#   'volume': 6099},
#  {'close': 1581.6,
#   'datetime': '2026-01-01 10:28:00',
#   'exchange_code': 'NSE',
#   'high': 1581.6,
#   'low': 1580.9,
#   'open': 1581.0,
#   'stock_code': 'RELIND',
#   'volume': 2357},
#  {'close': 1582.9,
#   'datetime': '2026-01-01 10:29:00',
#   'exchange_code': 'NSE',
#   'high': 1582.9,
#   'low': 1581.5,
#   'open': 1581.5,
#   'stock_code': 'RELIND',
#   'volume': 11056},
#  {'close': 1581.5,
#   'datetime': '2026-01-01 10:30:00',
#   'exchange_code': 'NSE',
#   'high': 1583.4,
#   'low': 1581.3,
#   'open': 1582.9,
#   'stock_code': 'RELIND',
#   'volume': 9688},
#  {'close': 1580.9,
#   'datetime': '2026-01-01 10:31:00',
#   'exchange_code': 'NSE',
#   'high': 1582.0,
#   'low': 1580.4,
#   'open': 1582.0,
#   'stock_code': 'RELIND',
#   'volume': 10547},
#  {'close': 1580.6,
#   'datetime': '2026-01-01 10:32:00',
#   'exchange_code': 'NSE',
#   'high': 1581.6,
#   'low': 1580.4,
#   'open': 1581.0,
#   'stock_code': 'RELIND',
#   'volume': 5304},
#  {'close': 1581.6,
#   'datetime': '2026-01-01 10:33:00',
#   'exchange_code': 'NSE',
#   'high': 1581.8,
#   'low': 1580.6,
#   'open': 1581.0,
#   'stock_code': 'RELIND',
#   'volume': 5616},
#  {'close': 1581.2,
#   'datetime': '2026-01-01 10:34:00',
#   'exchange_code': 'NSE',
#   'high': 1581.9,
#   'low': 1581.1,
#   'open': 1581.9,
#   'stock_code': 'RELIND',
#   'volume': 2502},
#  {'close': 1581.6,
#   'datetime': '2026-01-01 10:35:00',
#   'exchange_code': 'NSE',
#   'high': 1581.6,
#   'low': 1581.1,
#   'open': 1581.5,
#   'stock_code': 'RELIND',
#   'volume': 2020},
#  {'close': 1580.2,
#   'datetime': '2026-01-01 10:36:00',
#   'exchange_code': 'NSE',
#   'high': 1581.6,
#   'low': 1580.0,
#   'open': 1581.1,
#   'stock_code': 'RELIND',
#   'volume': 10977},
#  {'close': 1579.1,
#   'datetime': '2026-01-01 10:37:00',
#   'exchange_code': 'NSE',
#   'high': 1580.8,
#   'low': 1578.9,
#   'open': 1580.2,
#   'stock_code': 'RELIND',
#   'volume': 45945},
#  {'close': 1579.2,
#   'datetime': '2026-01-01 10:38:00',
#   'exchange_code': 'NSE',
#   'high': 1579.7,
#   'low': 1578.9,
#   'open': 1579.1,
#   'stock_code': 'RELIND',
#   'volume': 3833},
#  {'close': 1579.7,
#   'datetime': '2026-01-01 10:39:00',
#   'exchange_code': 'NSE',
#   'high': 1580.0,
#   'low': 1578.9,
#   'open': 1579.0,
#   'stock_code': 'RELIND',
#   'volume': 13627},
#  {'close': 1579.0,
#   'datetime': '2026-01-01 10:40:00',
#   'exchange_code': 'NSE',
#   'high': 1580.0,
#   'low': 1578.6,
#   'open': 1579.9,
#   'stock_code': 'RELIND',
#   'volume': 5858},
#  {'close': 1579.2,
#   'datetime': '2026-01-01 10:41:00',
#   'exchange_code': 'NSE',
#   'high': 1579.2,
#   'low': 1578.5,
#   'open': 1578.5,
#   'stock_code': 'RELIND',
#   'volume': 3386},
#  {'close': 1578.9,
#   'datetime': '2026-01-01 10:42:00',
#   'exchange_code': 'NSE',
#   'high': 1579.5,
#   'low': 1578.8,
#   'open': 1579.0,
#   'stock_code': 'RELIND',
#   'volume': 7255},
#  {'close': 1579.7,
#   'datetime': '2026-01-01 10:43:00',
#   'exchange_code': 'NSE',
#   'high': 1579.8,
#   'low': 1578.7,
#   'open': 1578.9,
#   'stock_code': 'RELIND',
#   'volume': 3431},
#  {'close': 1579.0,
#   'datetime': '2026-01-01 10:44:00',
#   'exchange_code': 'NSE',
#   'high': 1579.0,
#   'low': 1578.7,
#   'open': 1578.7,
#   'stock_code': 'RELIND',
#   'volume': 4563},
#  {'close': 1579.0,
#   'datetime': '2026-01-01 10:45:00',
#   'exchange_code': 'NSE',
#   'high': 1579.0,
#   'low': 1578.5,
#   'open': 1578.7,
#   'stock_code': 'RELIND',
#   'volume': 2915},
#  {'close': 1580.9,
#   'datetime': '2026-01-01 10:46:00',
#   'exchange_code': 'NSE',
#   'high': 1580.9,
#   'low': 1578.8,
#   'open': 1578.8,
#   'stock_code': 'RELIND',
#   'volume': 47841},
#  {'close': 1581.5,
#   'datetime': '2026-01-01 10:47:00',
#   'exchange_code': 'NSE',
#   'high': 1582.2,
#   'low': 1580.6,
#   'open': 1581.0,
#   'stock_code': 'RELIND',
#   'volume': 13218},
#  {'close': 1582.0,
#   'datetime': '2026-01-01 10:48:00',
#   'exchange_code': 'NSE',
#   'high': 1582.5,
#   'low': 1581.4,
#   'open': 1581.9,
#   'stock_code': 'RELIND',
#   'volume': 4649},
#  {'close': 1582.8,
#   'datetime': '2026-01-01 10:49:00',
#   'exchange_code': 'NSE',
#   'high': 1583.3,
#   'low': 1581.8,
#   'open': 1582.0,
#   'stock_code': 'RELIND',
#   'volume': 14782},
#  {'close': 1581.5,
#   'datetime': '2026-01-01 10:50:00',
#   'exchange_code': 'NSE',
#   'high': 1582.8,
#   'low': 1581.5,
#   'open': 1582.8,
#   'stock_code': 'RELIND',
#   'volume': 6469},
#  {'close': 1581.8,
#   'datetime': '2026-01-01 10:51:00',
#   'exchange_code': 'NSE',
#   'high': 1581.9,
#   'low': 1580.8,
#   'open': 1581.8,
#   'stock_code': 'RELIND',
#   'volume': 5314},
#  {'close': 1581.8,
#   'datetime': '2026-01-01 10:52:00',
#   'exchange_code': 'NSE',
#   'high': 1581.8,
#   'low': 1581.1,
#   'open': 1581.8,
#   'stock_code': 'RELIND',
#   'volume': 1612},
#  {'close': 1581.7,
#   'datetime': '2026-01-01 10:53:00',
#   'exchange_code': 'NSE',
#   'high': 1581.8,
#   'low': 1581.4,
#   'open': 1581.8,
#   'stock_code': 'RELIND',
#   'volume': 2032},
#  {'close': 1581.5,
#   'datetime': '2026-01-01 10:54:00',
#   'exchange_code': 'NSE',
#   'high': 1582.0,
#   'low': 1581.4,
#   'open': 1581.7,
#   'stock_code': 'RELIND',
#   'volume': 2955},
#  {'close': 1581.7,
#   'datetime': '2026-01-01 10:55:00',
#   'exchange_code': 'NSE',
#   'high': 1582.0,
#   'low': 1580.1,
#   'open': 1581.6,
#   'stock_code': 'RELIND',
#   'volume': 12087},
#  {'close': 1581.9,
#   'datetime': '2026-01-01 10:56:00',
#   'exchange_code': 'NSE',
#   'high': 1582.0,
#   'low': 1581.1,
#   'open': 1581.7,
#   'stock_code': 'RELIND',
#   'volume': 1424},
#  {'close': 1580.9,
#   'datetime': '2026-01-01 10:57:00',
#   'exchange_code': 'NSE',
#   'high': 1582.0,
#   'low': 1580.4,
#   'open': 1581.9,
#   'stock_code': 'RELIND',
#   'volume': 7720},
#  {'close': 1580.5,
#   'datetime': '2026-01-01 10:58:00',
#   'exchange_code': 'NSE',
#   'high': 1580.9,
#   'low': 1580.1,
#   'open': 1580.5,
#   'stock_code': 'RELIND',
#   'volume': 2755},
#  {'close': 1581.0,
#   'datetime': '2026-01-01 10:59:00',
#   'exchange_code': 'NSE',
#   'high': 1581.0,
#   'low': 1580.1,
#   'open': 1580.5,
#   'stock_code': 'RELIND',
#   'volume': 2268},
#  {'close': 1580.0,
#   'datetime': '2026-01-01 11:00:00',
#   'exchange_code': 'NSE',
#   'high': 1580.9,
#   'low': 1579.8,
#   'open': 1580.9,
#   'stock_code': 'RELIND',
#   'volume': 6297},
#  {'close': 1581.1,
#   'datetime': '2026-01-01 11:01:00',
#   'exchange_code': 'NSE',
#   'high': 1581.6,
#   'low': 1580.0,
#   'open': 1580.0,
#   'stock_code': 'RELIND',
#   'volume': 7884},
#  {'close': 1581.3,
#   'datetime': '2026-01-01 11:02:00',
#   'exchange_code': 'NSE',
#   'high': 1581.5,
#   'low': 1580.8,
#   'open': 1581.1,
#   'stock_code': 'RELIND',
#   'volume': 3096},
#  {'close': 1581.6,
#   'datetime': '2026-01-01 11:03:00',
#   'exchange_code': 'NSE',
#   'high': 1581.6,
#   'low': 1581.0,
#   'open': 1581.3,
#   'stock_code': 'RELIND',
#   'volume': 3024},
#  {'close': 1580.6,
#   'datetime': '2026-01-01 11:04:00',
#   'exchange_code': 'NSE',
#   'high': 1581.6,
#   'low': 1580.5,
#   'open': 1581.6,
#   'stock_code': 'RELIND',
#   'volume': 3913},
#  {'close': 1580.9,
#   'datetime': '2026-01-01 11:05:00',
#   'exchange_code': 'NSE',
#   'high': 1581.6,
#   'low': 1580.6,
#   'open': 1580.6,
#   'stock_code': 'RELIND',
#   'volume': 2662},
#  {'close': 1581.6,
#   'datetime': '2026-01-01 11:06:00',
#   'exchange_code': 'NSE',
#   'high': 1581.6,
#   'low': 1580.6,
#   'open': 1581.2,
#   'stock_code': 'RELIND',
#   'volume': 3496},
#  {'close': 1581.5,
#   'datetime': '2026-01-01 11:07:00',
#   'exchange_code': 'NSE',
#   'high': 1581.7,
#   'low': 1581.0,
#   'open': 1581.1,
#   'stock_code': 'RELIND',
#   'volume': 2445},
#  {'close': 1581.6,
#   'datetime': '2026-01-01 11:08:00',
#   'exchange_code': 'NSE',
#   'high': 1581.9,
#   'low': 1581.1,
#   'open': 1581.5,
#   'stock_code': 'RELIND',
#   'volume': 2442},
#  {'close': 1581.0,
#   'datetime': '2026-01-01 11:09:00',
#   'exchange_code': 'NSE',
#   'high': 1581.5,
#   'low': 1580.5,
#   'open': 1580.5,
#   'stock_code': 'RELIND',
#   'volume': 9769},
#  {'close': 1582.0,
#   'datetime': '2026-01-01 11:10:00',
#   'exchange_code': 'NSE',
#   'high': 1582.0,
#   'low': 1580.6,
#   'open': 1581.0,
#   'stock_code': 'RELIND',
#   'volume': 27770},
#  {'close': 1581.0,
#   'datetime': '2026-01-01 11:11:00',
#   'exchange_code': 'NSE',
#   'high': 1582.0,
#   'low': 1580.7,
#   'open': 1581.5,
#   'stock_code': 'RELIND',
#   'volume': 4450},
#  {'close': 1581.2,
#   'datetime': '2026-01-01 11:12:00',
#   'exchange_code': 'NSE',
#   'high': 1581.7,
#   'low': 1580.7,
#   'open': 1581.0,
#   'stock_code': 'RELIND',
#   'volume': 4500},
#  {'close': 1580.7,
#   'datetime': '2026-01-01 11:13:00',
#   'exchange_code': 'NSE',
#   'high': 1581.8,
#   'low': 1580.7,
#   'open': 1581.2,
#   'stock_code': 'RELIND',
#   'volume': 8149},
#  {'close': 1580.4,
#   'datetime': '2026-01-01 11:14:00',
#   'exchange_code': 'NSE',
#   'high': 1581.3,
#   'low': 1580.4,
#   'open': 1580.7,
#   'stock_code': 'RELIND',
#   'volume': 4382},
#  {'close': 1580.8,
#   'datetime': '2026-01-01 11:15:00',
#   'exchange_code': 'NSE',
#   'high': 1581.0,
#   'low': 1580.4,
#   'open': 1580.4,
#   'stock_code': 'RELIND',
#   'volume': 2241},
#  {'close': 1580.5,
#   'datetime': '2026-01-01 11:16:00',
#   'exchange_code': 'NSE',
#   'high': 1581.0,
#   'low': 1580.4,
#   'open': 1580.6,
#   'stock_code': 'RELIND',
#   'volume': 3049},
#  {'close': 1580.6,
#   'datetime': '2026-01-01 11:17:00',
#   'exchange_code': 'NSE',
#   'high': 1581.0,
#   'low': 1580.3,
#   'open': 1580.5,
#   'stock_code': 'RELIND',
#   'volume': 1786},
#  {'close': 1580.4,
#   'datetime': '2026-01-01 11:18:00',
#   'exchange_code': 'NSE',
#   'high': 1581.3,
#   'low': 1580.1,
#   'open': 1580.6,
#   'stock_code': 'RELIND',
#   'volume': 46930},
#  {'close': 1580.0,
#   'datetime': '2026-01-01 11:19:00',
#   'exchange_code': 'NSE',
#   'high': 1580.6,
#   'low': 1579.9,
#   'open': 1579.9,
#   'stock_code': 'RELIND',
#   'volume': 3027},
#  {'close': 1580.2,
#   'datetime': '2026-01-01 11:20:00',
#   'exchange_code': 'NSE',
#   'high': 1580.2,
#   'low': 1580.0,
#   'open': 1580.0,
#   'stock_code': 'RELIND',
#   'volume': 1519},
#  {'close': 1580.5,
#   'datetime': '2026-01-01 11:21:00',
#   'exchange_code': 'NSE',
#   'high': 1580.8,
#   'low': 1580.0,
#   'open': 1580.0,
#   'stock_code': 'RELIND',
#   'volume': 3181},
#  {'close': 1580.3,
#   'datetime': '2026-01-01 11:22:00',
#   'exchange_code': 'NSE',
#   'high': 1580.8,
#   'low': 1579.7,
#   'open': 1580.8,
#   'stock_code': 'RELIND',
#   'volume': 5716},
#  {'close': 1580.1,
#   'datetime': '2026-01-01 11:23:00',
#   'exchange_code': 'NSE',
#   'high': 1580.5,
#   'low': 1580.0,
#   'open': 1580.0,
#   'stock_code': 'RELIND',
#   'volume': 1434},
#  {'close': 1580.2,
#   'datetime': '2026-01-01 11:24:00',
#   'exchange_code': 'NSE',
#   'high': 1580.6,
#   'low': 1580.0,
#   'open': 1580.3,
#   'stock_code': 'RELIND',
#   'volume': 4326},
#  {'close': 1580.0,
#   'datetime': '2026-01-01 11:25:00',
#   'exchange_code': 'NSE',
#   'high': 1580.6,
#   'low': 1580.0,
#   'open': 1580.0,
#   'stock_code': 'RELIND',
#   'volume': 3264},
#  {'close': 1580.0,
#   'datetime': '2026-01-01 11:26:00',
#   'exchange_code': 'NSE',
#   'high': 1580.0,
#   'low': 1579.6,
#   'open': 1580.0,
#   'stock_code': 'RELIND',
#   'volume': 2538},
#  {'close': 1579.6,
#   'datetime': '2026-01-01 11:27:00',
#   'exchange_code': 'NSE',
#   'high': 1580.5,
#   'low': 1579.6,
#   'open': 1580.0,
#   'stock_code': 'RELIND',
#   'volume': 15693},
#  {'close': 1579.0,
#   'datetime': '2026-01-01 11:28:00',
#   'exchange_code': 'NSE',
#   'high': 1579.7,
#   'low': 1578.6,
#   'open': 1579.6,
#   'stock_code': 'RELIND',
#   'volume': 4484},
#  {'close': 1579.0,
#   'datetime': '2026-01-01 11:29:00',
#   'exchange_code': 'NSE',
#   'high': 1579.5,
#   'low': 1578.6,
#   'open': 1579.0,
#   'stock_code': 'RELIND',
#   'volume': 4018},
#  {'close': 1578.1,
#   'datetime': '2026-01-01 11:30:00',
#   'exchange_code': 'NSE',
#   'high': 1579.0,
#   'low': 1578.0,
#   'open': 1578.8,
#   'stock_code': 'RELIND',
#   'volume': 16643},
#  {'close': 1579.1,
#   'datetime': '2026-01-01 11:31:00',
#   'exchange_code': 'NSE',
#   'high': 1579.5,
#   'low': 1578.1,
#   'open': 1578.1,
#   'stock_code': 'RELIND',
#   'volume': 6154},
#  {'close': 1578.4,
#   'datetime': '2026-01-01 11:32:00',
#   'exchange_code': 'NSE',
#   'high': 1579.1,
#   'low': 1578.4,
#   'open': 1578.9,
#   'stock_code': 'RELIND',
#   'volume': 3088},
#  {'close': 1578.5,
#   'datetime': '2026-01-01 11:33:00',
#   'exchange_code': 'NSE',
#   'high': 1579.1,
#   'low': 1578.0,
#   'open': 1578.4,
#   'stock_code': 'RELIND',
#   'volume': 3593},
#  {'close': 1577.7,
#   'datetime': '2026-01-01 11:34:00',
#   'exchange_code': 'NSE',
#   'high': 1578.5,
#   'low': 1577.2,
#   'open': 1578.5,
#   'stock_code': 'RELIND',
#   'volume': 6540},
#  {'close': 1576.8,
#   'datetime': '2026-01-01 11:35:00',
#   'exchange_code': 'NSE',
#   'high': 1577.9,
#   'low': 1576.3,
#   'open': 1577.6,
#   'stock_code': 'RELIND',
#   'volume': 12588},
#  {'close': 1576.7,
#   'datetime': '2026-01-01 11:36:00',
#   'exchange_code': 'NSE',
#   'high': 1577.5,
#   'low': 1576.5,
#   'open': 1576.8,
#   'stock_code': 'RELIND',
#   'volume': 10562},
#  {'close': 1577.9,
#   'datetime': '2026-01-01 11:37:00',
#   'exchange_code': 'NSE',
#   'high': 1578.0,
#   'low': 1576.7,
#   'open': 1577.3,
#   'stock_code': 'RELIND',
#   'volume': 3884},
#  {'close': 1578.0,
#   'datetime': '2026-01-01 11:38:00',
#   'exchange_code': 'NSE',
#   'high': 1578.4,
#   'low': 1577.6,
#   'open': 1577.9,
#   'stock_code': 'RELIND',
#   'volume': 3507},
#  {'close': 1578.2,
#   'datetime': '2026-01-01 11:39:00',
#   'exchange_code': 'NSE',
#   'high': 1578.5,
#   'low': 1577.6,
#   'open': 1577.8,
#   'stock_code': 'RELIND',
#   'volume': 4218},
#  {'close': 1578.0,
#   'datetime': '2026-01-01 11:40:00',
#   'exchange_code': 'NSE',
#   'high': 1578.2,
#   'low': 1577.3,
#   'open': 1577.8,
#   'stock_code': 'RELIND',
#   'volume': 1267},
#  {'close': 1577.6,
#   'datetime': '2026-01-01 11:41:00',
#   'exchange_code': 'NSE',
#   'high': 1578.0,
#   'low': 1577.5,
#   'open': 1577.5,
#   'stock_code': 'RELIND',
#   'volume': 1746},
#  {'close': 1577.6,
#   'datetime': '2026-01-01 11:42:00',
#   'exchange_code': 'NSE',
#   'high': 1578.0,
#   'low': 1577.6,
#   'open': 1577.6,
#   'stock_code': 'RELIND',
#   'volume': 1363},
#  {'close': 1577.1,
#   'datetime': '2026-01-01 11:43:00',
#   'exchange_code': 'NSE',
#   'high': 1577.9,
#   'low': 1577.1,
#   'open': 1577.6,
#   'stock_code': 'RELIND',
#   'volume': 2458},
#  {'close': 1577.5,
#   'datetime': '2026-01-01 11:44:00',
#   'exchange_code': 'NSE',
#   'high': 1577.5,
#   'low': 1576.9,
#   'open': 1577.4,
#   'stock_code': 'RELIND',
#   'volume': 5569},
#  {'close': 1577.9,
#   'datetime': '2026-01-01 11:45:00',
#   'exchange_code': 'NSE',
#   'high': 1577.9,
#   'low': 1577.1,
#   'open': 1577.1,
#   'stock_code': 'RELIND',
#   'volume': 7010},
#  {'close': 1577.7,
#   'datetime': '2026-01-01 11:46:00',
#   'exchange_code': 'NSE',
#   'high': 1577.9,
#   'low': 1577.6,
#   'open': 1577.7,
#   'stock_code': 'RELIND',
#   'volume': 1402},
#  {'close': 1577.3,
#   'datetime': '2026-01-01 11:47:00',
#   'exchange_code': 'NSE',
#   'high': 1577.7,
#   'low': 1577.2,
#   'open': 1577.7,
#   'stock_code': 'RELIND',
#   'volume': 1514},
#  {'close': 1577.3,
#   'datetime': '2026-01-01 11:48:00',
#   'exchange_code': 'NSE',
#   'high': 1577.7,
#   'low': 1577.2,
#   'open': 1577.3,
#   'stock_code': 'RELIND',
#   'volume': 2403},
#  {'close': 1577.5,
#   'datetime': '2026-01-01 11:49:00',
#   'exchange_code': 'NSE',
#   'high': 1577.7,
#   'low': 1577.3,
#   'open': 1577.5,
#   'stock_code': 'RELIND',
#   'volume': 4828},
#  {'close': 1577.1,
#   'datetime': '2026-01-01 11:50:00',
#   'exchange_code': 'NSE',
#   'high': 1577.7,
#   'low': 1576.9,
#   'open': 1577.5,
#   'stock_code': 'RELIND',
#   'volume': 6267},
#  {'close': 1577.2,
#   'datetime': '2026-01-01 11:51:00',
#   'exchange_code': 'NSE',
#   'high': 1577.8,
#   'low': 1577.1,
#   'open': 1577.8,
#   'stock_code': 'RELIND',
#   'volume': 2627},
#  {'close': 1576.8,
#   'datetime': '2026-01-01 11:52:00',
#   'exchange_code': 'NSE',
#   'high': 1577.7,
#   'low': 1576.8,
#   'open': 1577.2,
#   'stock_code': 'RELIND',
#   'volume': 3549},
#  {'close': 1576.4,
#   'datetime': '2026-01-01 11:53:00',
#   'exchange_code': 'NSE',
#   'high': 1577.0,
#   'low': 1576.1,
#   'open': 1576.6,
#   'stock_code': 'RELIND',
#   'volume': 6532},
#  {'close': 1576.6,
#   'datetime': '2026-01-01 11:54:00',
#   'exchange_code': 'NSE',
#   'high': 1577.5,
#   'low': 1576.5,
#   'open': 1576.5,
#   'stock_code': 'RELIND',
#   'volume': 5670},
#  {'close': 1577.1,
#   'datetime': '2026-01-01 11:55:00',
#   'exchange_code': 'NSE',
#   'high': 1577.4,
#   'low': 1576.6,
#   'open': 1576.6,
#   'stock_code': 'RELIND',
#   'volume': 9353},
#  {'close': 1576.7,
#   'datetime': '2026-01-01 11:56:00',
#   'exchange_code': 'NSE',
#   'high': 1577.9,
#   'low': 1576.7,
#   'open': 1577.4,
#   'stock_code': 'RELIND',
#   'volume': 9094},
#  {'close': 1577.1,
#   'datetime': '2026-01-01 11:57:00',
#   'exchange_code': 'NSE',
#   'high': 1577.4,
#   'low': 1576.7,
#   'open': 1577.1,
#   'stock_code': 'RELIND',
#   'volume': 1183},
#  {'close': 1577.0,
#   'datetime': '2026-01-01 11:58:00',
#   'exchange_code': 'NSE',
#   'high': 1577.4,
#   'low': 1576.7,
#   'open': 1577.1,
#   'stock_code': 'RELIND',
#   'volume': 2718},
#  {'close': 1577.5,
#   'datetime': '2026-01-01 11:59:00',
#   'exchange_code': 'NSE',
#   'high': 1577.5,
#   'low': 1577.0,
#   'open': 1577.0,
#   'stock_code': 'RELIND',
#   'volume': 2001},
#  {'close': 1577.3,
#   'datetime': '2026-01-01 12:00:00',
#   'exchange_code': 'NSE',
#   'high': 1577.7,
#   'low': 1577.1,
#   'open': 1577.2,
#   'stock_code': 'RELIND',
#   'volume': 4250},
#  {'close': 1577.6,
#   'datetime': '2026-01-01 12:01:00',
#   'exchange_code': 'NSE',
#   'high': 1577.8,
#   'low': 1577.3,
#   'open': 1577.3,
#   'stock_code': 'RELIND',
#   'volume': 1211},
#  {'close': 1577.5,
#   'datetime': '2026-01-01 12:02:00',
#   'exchange_code': 'NSE',
#   'high': 1577.7,
#   'low': 1577.4,
#   'open': 1577.5,
#   'stock_code': 'RELIND',
#   'volume': 4056},
#  {'close': 1577.3,
#   'datetime': '2026-01-01 12:03:00',
#   'exchange_code': 'NSE',
#   'high': 1577.9,
#   'low': 1577.3,
#   'open': 1577.6,
#   'stock_code': 'RELIND',
#   'volume': 2345},
#  {'close': 1577.0,
#   'datetime': '2026-01-01 12:04:00',
#   'exchange_code': 'NSE',
#   'high': 1577.5,
#   'low': 1577.0,
#   'open': 1577.5,
#   'stock_code': 'RELIND',
#   'volume': 5321},
#  {'close': 1576.7,
#   'datetime': '2026-01-01 12:05:00',
#   'exchange_code': 'NSE',
#   'high': 1577.4,
#   'low': 1576.7,
#   'open': 1577.0,
#   'stock_code': 'RELIND',
#   'volume': 4105},
#  {'close': 1577.0,
#   'datetime': '2026-01-01 12:06:00',
#   'exchange_code': 'NSE',
#   'high': 1577.2,
#   'low': 1576.6,
#   'open': 1576.7,
#   'stock_code': 'RELIND',
#   'volume': 1573},
#  {'close': 1576.9,
#   'datetime': '2026-01-01 12:07:00',
#   'exchange_code': 'NSE',
#   'high': 1577.3,
#   'low': 1576.8,
#   'open': 1577.0,
#   'stock_code': 'RELIND',
#   'volume': 4291},
#  {'close': 1576.2,
#   'datetime': '2026-01-01 12:08:00',
#   'exchange_code': 'NSE',
#   'high': 1577.3,
#   'low': 1576.2,
#   'open': 1576.8,
#   'stock_code': 'RELIND',
#   'volume': 2784},
#  {'close': 1576.0,
#   'datetime': '2026-01-01 12:09:00',
#   'exchange_code': 'NSE',
#   'high': 1576.6,
#   'low': 1575.5,
#   'open': 1576.2,
#   'stock_code': 'RELIND',
#   'volume': 12342},
#  {'close': 1576.3,
#   'datetime': '2026-01-01 12:10:00',
#   'exchange_code': 'NSE',
#   'high': 1576.7,
#   'low': 1575.7,
#   'open': 1576.0,
#   'stock_code': 'RELIND',
#   'volume': 3505},
#  {'close': 1576.6,
#   'datetime': '2026-01-01 12:11:00',
#   'exchange_code': 'NSE',
#   'high': 1576.7,
#   'low': 1576.1,
#   'open': 1576.3,
#   'stock_code': 'RELIND',
#   'volume': 4284},
#  {'close': 1576.8,
#   'datetime': '2026-01-01 12:12:00',
#   'exchange_code': 'NSE',
#   'high': 1577.0,
#   'low': 1576.2,
#   'open': 1576.4,
#   'stock_code': 'RELIND',
#   'volume': 6342},
#  {'close': 1577.5,
#   'datetime': '2026-01-01 12:13:00',
#   'exchange_code': 'NSE',
#   'high': 1578.0,
#   'low': 1576.5,
#   'open': 1577.0,
#   'stock_code': 'RELIND',
#   'volume': 17162},
#  {'close': 1578.1,
#   'datetime': '2026-01-01 12:14:00',
#   'exchange_code': 'NSE',
#   'high': 1578.5,
#   'low': 1577.5,
#   'open': 1577.5,
#   'stock_code': 'RELIND',
#   'volume': 48600},
#  {'close': 1578.2,
#   'datetime': '2026-01-01 12:15:00',
#   'exchange_code': 'NSE',
#   'high': 1578.3,
#   'low': 1577.1,
#   'open': 1577.7,
#   'stock_code': 'RELIND',
#   'volume': 22472},
#  {'close': 1576.7,
#   'datetime': '2026-01-01 12:16:00',
#   'exchange_code': 'NSE',
#   'high': 1578.3,
#   'low': 1576.5,
#   'open': 1578.2,
#   'stock_code': 'RELIND',
#   'volume': 22521},
#  {'close': 1575.5,
#   'datetime': '2026-01-01 12:17:00',
#   'exchange_code': 'NSE',
#   'high': 1576.5,
#   'low': 1575.2,
#   'open': 1576.5,
#   'stock_code': 'RELIND',
#   'volume': 22694},
#  {'close': 1575.1,
#   'datetime': '2026-01-01 12:18:00',
#   'exchange_code': 'NSE',
#   'high': 1575.5,
#   'low': 1575.0,
#   'open': 1575.5,
#   'stock_code': 'RELIND',
#   'volume': 16874},
#  {'close': 1576.0,
#   'datetime': '2026-01-01 12:19:00',
#   'exchange_code': 'NSE',
#   'high': 1576.0,
#   'low': 1574.3,
#   'open': 1575.1,
#   'stock_code': 'RELIND',
#   'volume': 58028},
#  {'close': 1576.6,
#   'datetime': '2026-01-01 12:20:00',
#   'exchange_code': 'NSE',
#   'high': 1576.6,
#   'low': 1575.5,
#   'open': 1575.8,
#   'stock_code': 'RELIND',
#   'volume': 13056},
#  {'close': 1577.5,
#   'datetime': '2026-01-01 12:21:00',
#   'exchange_code': 'NSE',
#   'high': 1577.5,
#   'low': 1576.0,
#   'open': 1576.6,
#   'stock_code': 'RELIND',
#   'volume': 9934},
#  {'close': 1577.2,
#   'datetime': '2026-01-01 12:22:00',
#   'exchange_code': 'NSE',
#   'high': 1577.5,
#   'low': 1577.1,
#   'open': 1577.5,
#   'stock_code': 'RELIND',
#   'volume': 4588},
#  {'close': 1577.0,
#   'datetime': '2026-01-01 12:23:00',
#   'exchange_code': 'NSE',
#   'high': 1577.5,
#   'low': 1576.2,
#   'open': 1577.5,
#   'stock_code': 'RELIND',
#   'volume': 3552},
#  {'close': 1577.3,
#   'datetime': '2026-01-01 12:24:00',
#   'exchange_code': 'NSE',
#   'high': 1577.3,
#   'low': 1576.2,
#   'open': 1576.7,
#   'stock_code': 'RELIND',
#   'volume': 5809},
#  {'close': 1577.6,
#   'datetime': '2026-01-01 12:25:00',
#   'exchange_code': 'NSE',
#   'high': 1577.6,
#   'low': 1577.0,
#   'open': 1577.3,
#   'stock_code': 'RELIND',
#   'volume': 1474},
#  {'close': 1578.4,
#   'datetime': '2026-01-01 12:26:00',
#   'exchange_code': 'NSE',
#   'high': 1578.4,
#   'low': 1577.3,
#   'open': 1577.6,
#   'stock_code': 'RELIND',
#   'volume': 11273},
#  {'close': 1578.1,
#   'datetime': '2026-01-01 12:27:00',
#   'exchange_code': 'NSE',
#   'high': 1578.5,
#   'low': 1577.7,
#   'open': 1578.4,
#   'stock_code': 'RELIND',
#   'volume': 7042},
#  {'close': 1578.3,
#   'datetime': '2026-01-01 12:28:00',
#   'exchange_code': 'NSE',
#   'high': 1578.4,
#   'low': 1577.7,
#   'open': 1578.2,
#   'stock_code': 'RELIND',
#   'volume': 4312},
#  {'close': 1577.5,
#   'datetime': '2026-01-01 12:29:00',
#   'exchange_code': 'NSE',
#   'high': 1578.5,
#   'low': 1577.5,
#   'open': 1578.0,
#   'stock_code': 'RELIND',
#   'volume': 3494},
#  {'close': 1578.0,
#   'datetime': '2026-01-01 12:30:00',
#   'exchange_code': 'NSE',
#   'high': 1578.2,
#   'low': 1577.3,
#   'open': 1577.9,
#   'stock_code': 'RELIND',
#   'volume': 3403},
#  {'close': 1578.0,
#   'datetime': '2026-01-01 12:31:00',
#   'exchange_code': 'NSE',
#   'high': 1578.0,
#   'low': 1577.4,
#   'open': 1578.0,
#   'stock_code': 'RELIND',
#   'volume': 1496},
#  {'close': 1578.0,
#   'datetime': '2026-01-01 12:32:00',
#   'exchange_code': 'NSE',
#   'high': 1578.5,
#   'low': 1578.0,
#   'open': 1578.0,
#   'stock_code': 'RELIND',
#   'volume': 3139},
#  {'close': 1578.5,
#   'datetime': '2026-01-01 12:33:00',
#   'exchange_code': 'NSE',
#   'high': 1578.5,
#   'low': 1578.0,
#   'open': 1578.0,
#   'stock_code': 'RELIND',
#   'volume': 3852},
#  {'close': 1579.0,
#   'datetime': '2026-01-01 12:34:00',
#   'exchange_code': 'NSE',
#   'high': 1579.0,
#   'low': 1578.2,
#   'open': 1578.5,
#   'stock_code': 'RELIND',
#   'volume': 3785},
#  {'close': 1578.0,
#   'datetime': '2026-01-01 12:35:00',
#   'exchange_code': 'NSE',
#   'high': 1579.0,
#   'low': 1577.9,
#   'open': 1578.8,
#   'stock_code': 'RELIND',
#   'volume': 21466},
#  {'close': 1577.4,
#   'datetime': '2026-01-01 12:36:00',
#   'exchange_code': 'NSE',
#   'high': 1578.3,
#   'low': 1577.3,
#   'open': 1577.8,
#   'stock_code': 'RELIND',
#   'volume': 4209},
#  {'close': 1577.4,
#   'datetime': '2026-01-01 12:37:00',
#   'exchange_code': 'NSE',
#   'high': 1577.8,
#   'low': 1577.2,
#   'open': 1577.5,
#   'stock_code': 'RELIND',
#   'volume': 33474},
#  {'close': 1576.3,
#   'datetime': '2026-01-01 12:38:00',
#   'exchange_code': 'NSE',
#   'high': 1577.4,
#   'low': 1576.2,
#   'open': 1577.3,
#   'stock_code': 'RELIND',
#   'volume': 28363},
#  {'close': 1575.8,
#   'datetime': '2026-01-01 12:39:00',
#   'exchange_code': 'NSE',
#   'high': 1576.4,
#   'low': 1575.3,
#   'open': 1576.3,
#   'stock_code': 'RELIND',
#   'volume': 49327},
#  {'close': 1576.6,
#   'datetime': '2026-01-01 12:40:00',
#   'exchange_code': 'NSE',
#   'high': 1576.6,
#   'low': 1575.3,
#   'open': 1575.5,
#   'stock_code': 'RELIND',
#   'volume': 42170},
#  {'close': 1575.7,
#   'datetime': '2026-01-01 12:41:00',
#   'exchange_code': 'NSE',
#   'high': 1576.6,
#   'low': 1575.5,
#   'open': 1576.6,
#   'stock_code': 'RELIND',
#   'volume': 2876},
#  {'close': 1576.5,
#   'datetime': '2026-01-01 12:42:00',
#   'exchange_code': 'NSE',
#   'high': 1576.6,
#   'low': 1575.5,
#   'open': 1575.8,
#   'stock_code': 'RELIND',
#   'volume': 19399},
#  {'close': 1577.5,
#   'datetime': '2026-01-01 12:43:00',
#   'exchange_code': 'NSE',
#   'high': 1578.1,
#   'low': 1576.2,
#   'open': 1576.2,
#   'stock_code': 'RELIND',
#   'volume': 36354},
#  {'close': 1577.9,
#   'datetime': '2026-01-01 12:44:00',
#   'exchange_code': 'NSE',
#   'high': 1578.3,
#   'low': 1576.8,
#   'open': 1577.4,
#   'stock_code': 'RELIND',
#   'volume': 65915},
#  {'close': 1577.8,
#   'datetime': '2026-01-01 12:45:00',
#   'exchange_code': 'NSE',
#   'high': 1578.7,
#   'low': 1577.3,
#   'open': 1578.0,
#   'stock_code': 'RELIND',
#   'volume': 56823},
#  {'close': 1578.9,
#   'datetime': '2026-01-01 12:46:00',
#   'exchange_code': 'NSE',
#   'high': 1578.9,
#   'low': 1577.8,
#   'open': 1577.8,
#   'stock_code': 'RELIND',
#   'volume': 11877},
#  {'close': 1579.2,
#   'datetime': '2026-01-01 12:47:00',
#   'exchange_code': 'NSE',
#   'high': 1579.9,
#   'low': 1578.6,
#   'open': 1578.8,
#   'stock_code': 'RELIND',
#   'volume': 30867},
#  {'close': 1580.4,
#   'datetime': '2026-01-01 12:48:00',
#   'exchange_code': 'NSE',
#   'high': 1580.4,
#   'low': 1579.2,
#   'open': 1579.2,
#   'stock_code': 'RELIND',
#   'volume': 53105},
#  {'close': 1580.0,
#   'datetime': '2026-01-01 12:49:00',
#   'exchange_code': 'NSE',
#   'high': 1580.8,
#   'low': 1580.0,
#   'open': 1580.4,
#   'stock_code': 'RELIND',
#   'volume': 16496},
#  {'close': 1579.0,
#   'datetime': '2026-01-01 12:50:00',
#   'exchange_code': 'NSE',
#   'high': 1580.0,
#   'low': 1578.7,
#   'open': 1580.0,
#   'stock_code': 'RELIND',
#   'volume': 30791},
#  {'close': 1578.9,
#   'datetime': '2026-01-01 12:51:00',
#   'exchange_code': 'NSE',
#   'high': 1579.4,
#   'low': 1578.1,
#   'open': 1578.7,
#   'stock_code': 'RELIND',
#   'volume': 29527},
#  {'close': 1578.0,
#   'datetime': '2026-01-01 12:52:00',
#   'exchange_code': 'NSE',
#   'high': 1578.9,
#   'low': 1577.4,
#   'open': 1578.9,
#   'stock_code': 'RELIND',
#   'volume': 7680},
#  {'close': 1577.8,
#   'datetime': '2026-01-01 12:53:00',
#   'exchange_code': 'NSE',
#   'high': 1578.5,
#   'low': 1577.6,
#   'open': 1578.0,
#   'stock_code': 'RELIND',
#   'volume': 3279},
#  {'close': 1577.4,
#   'datetime': '2026-01-01 12:54:00',
#   'exchange_code': 'NSE',
#   'high': 1577.8,
#   'low': 1577.0,
#   'open': 1577.8,
#   'stock_code': 'RELIND',
#   'volume': 16568},
#  {'close': 1577.6,
#   'datetime': '2026-01-01 12:55:00',
#   'exchange_code': 'NSE',
#   'high': 1577.6,
#   'low': 1576.8,
#   'open': 1577.4,
#   'stock_code': 'RELIND',
#   'volume': 5585},
#  {'close': 1577.0,
#   'datetime': '2026-01-01 12:56:00',
#   'exchange_code': 'NSE',
#   'high': 1577.6,
#   'low': 1576.9,
#   'open': 1577.2,
#   'stock_code': 'RELIND',
#   'volume': 7400},
#  {'close': 1576.8,
#   'datetime': '2026-01-01 12:57:00',
#   'exchange_code': 'NSE',
#   'high': 1577.3,
#   'low': 1576.8,
#   'open': 1577.0,
#   'stock_code': 'RELIND',
#   'volume': 4620},
#  {'close': 1576.9,
#   'datetime': '2026-01-01 12:58:00',
#   'exchange_code': 'NSE',
#   'high': 1577.5,
#   'low': 1576.8,
#   'open': 1576.8,
#   'stock_code': 'RELIND',
#   'volume': 5975},
#  {'close': 1575.8,
#   'datetime': '2026-01-01 12:59:00',
#   'exchange_code': 'NSE',
#   'high': 1577.0,
#   'low': 1575.8,
#   'open': 1576.9,
#   'stock_code': 'RELIND',
#   'volume': 9315},
#  {'close': 1576.0,
#   'datetime': '2026-01-01 13:00:00',
#   'exchange_code': 'NSE',
#   'high': 1576.0,
#   'low': 1575.8,
#   'open': 1576.0,
#   'stock_code': 'RELIND',
#   'volume': 7070},
#  {'close': 1575.4,
#   'datetime': '2026-01-01 13:01:00',
#   'exchange_code': 'NSE',
#   'high': 1576.0,
#   'low': 1575.1,
#   'open': 1575.9,
#   'stock_code': 'RELIND',
#   'volume': 29699},
#  {'close': 1575.6,
#   'datetime': '2026-01-01 13:02:00',
#   'exchange_code': 'NSE',
#   'high': 1575.6,
#   'low': 1575.0,
#   'open': 1575.0,
#   'stock_code': 'RELIND',
#   'volume': 12962},
#  {'close': 1575.6,
#   'datetime': '2026-01-01 13:03:00',
#   'exchange_code': 'NSE',
#   'high': 1575.8,
#   'low': 1575.3,
#   'open': 1575.6,
#   'stock_code': 'RELIND',
#   'volume': 1278},
#  {'close': 1576.0,
#   'datetime': '2026-01-01 13:04:00',
#   'exchange_code': 'NSE',
#   'high': 1576.6,
#   'low': 1575.6,
#   'open': 1575.6,
#   'stock_code': 'RELIND',
#   'volume': 9741},
#  {'close': 1575.4,
#   'datetime': '2026-01-01 13:05:00',
#   'exchange_code': 'NSE',
#   'high': 1576.8,
#   'low': 1575.1,
#   'open': 1576.0,
#   'stock_code': 'RELIND',
#   'volume': 18198},
#  {'close': 1575.6,
#   'datetime': '2026-01-01 13:06:00',
#   'exchange_code': 'NSE',
#   'high': 1575.8,
#   'low': 1575.2,
#   'open': 1575.4,
#   'stock_code': 'RELIND',
#   'volume': 5359},
#  {'close': 1574.8,
#   'datetime': '2026-01-01 13:07:00',
#   'exchange_code': 'NSE',
#   'high': 1575.8,
#   'low': 1574.8,
#   'open': 1575.6,
#   'stock_code': 'RELIND',
#   'volume': 16054},
#  {'close': 1575.0,
#   'datetime': '2026-01-01 13:08:00',
#   'exchange_code': 'NSE',
#   'high': 1575.0,
#   'low': 1574.7,
#   'open': 1575.0,
#   'stock_code': 'RELIND',
#   'volume': 2833},
#  {'close': 1575.5,
#   'datetime': '2026-01-01 13:09:00',
#   'exchange_code': 'NSE',
#   'high': 1575.8,
#   'low': 1574.9,
#   'open': 1574.9,
#   'stock_code': 'RELIND',
#   'volume': 3533},
#  {'close': 1575.3,
#   'datetime': '2026-01-01 13:10:00',
#   'exchange_code': 'NSE',
#   'high': 1575.8,
#   'low': 1575.3,
#   'open': 1575.5,
#   'stock_code': 'RELIND',
#   'volume': 4008},
#  {'close': 1575.3,
#   'datetime': '2026-01-01 13:11:00',
#   'exchange_code': 'NSE',
#   'high': 1575.3,
#   'low': 1575.0,
#   'open': 1575.0,
#   'stock_code': 'RELIND',
#   'volume': 1222},
#  {'close': 1574.7,
#   'datetime': '2026-01-01 13:12:00',
#   'exchange_code': 'NSE',
#   'high': 1575.3,
#   'low': 1574.4,
#   'open': 1575.3,
#   'stock_code': 'RELIND',
#   'volume': 4495},
#  {'close': 1575.0,
#   'datetime': '2026-01-01 13:13:00',
#   'exchange_code': 'NSE',
#   'high': 1575.2,
#   'low': 1574.7,
#   'open': 1574.7,
#   'stock_code': 'RELIND',
#   'volume': 1976},
#  {'close': 1575.2,
#   'datetime': '2026-01-01 13:14:00',
#   'exchange_code': 'NSE',
#   'high': 1575.3,
#   'low': 1574.7,
#   'open': 1574.7,
#   'stock_code': 'RELIND',
#   'volume': 2900},
#  {'close': 1575.6,
#   'datetime': '2026-01-01 13:15:00',
#   'exchange_code': 'NSE',
#   'high': 1575.6,
#   'low': 1574.8,
#   'open': 1574.8,
#   'stock_code': 'RELIND',
#   'volume': 5469},
#  {'close': 1575.6,
#   'datetime': '2026-01-01 13:16:00',
#   'exchange_code': 'NSE',
#   'high': 1576.0,
#   'low': 1575.3,
#   'open': 1575.6,
#   'stock_code': 'RELIND',
#   'volume': 1265},
#  {'close': 1575.8,
#   'datetime': '2026-01-01 13:17:00',
#   'exchange_code': 'NSE',
#   'high': 1576.1,
#   'low': 1575.6,
#   'open': 1575.6,
#   'stock_code': 'RELIND',
#   'volume': 2298},
#  {'close': 1575.9,
#   'datetime': '2026-01-01 13:18:00',
#   'exchange_code': 'NSE',
#   'high': 1575.9,
#   'low': 1575.3,
#   'open': 1575.5,
#   'stock_code': 'RELIND',
#   'volume': 3357},
#  {'close': 1575.9,
#   'datetime': '2026-01-01 13:19:00',
#   'exchange_code': 'NSE',
#   'high': 1576.5,
#   'low': 1575.0,
#   'open': 1575.3,
#   'stock_code': 'RELIND',
#   'volume': 14211},
#  {'close': 1575.4,
#   'datetime': '2026-01-01 13:20:00',
#   'exchange_code': 'NSE',
#   'high': 1576.4,
#   'low': 1575.2,
#   'open': 1576.4,
#   'stock_code': 'RELIND',
#   'volume': 3109},
#  {'close': 1575.0,
#   'datetime': '2026-01-01 13:21:00',
#   'exchange_code': 'NSE',
#   'high': 1575.5,
#   'low': 1574.7,
#   'open': 1575.1,
#   'stock_code': 'RELIND',
#   'volume': 2370},
#  {'close': 1574.0,
#   'datetime': '2026-01-01 13:22:00',
#   'exchange_code': 'NSE',
#   'high': 1575.1,
#   'low': 1574.0,
#   'open': 1575.1,
#   'stock_code': 'RELIND',
#   'volume': 6845},
#  {'close': 1573.8,
#   'datetime': '2026-01-01 13:23:00',
#   'exchange_code': 'NSE',
#   'high': 1574.1,
#   'low': 1573.1,
#   'open': 1574.0,
#   'stock_code': 'RELIND',
#   'volume': 62549},
#  {'close': 1573.7,
#   'datetime': '2026-01-01 13:24:00',
#   'exchange_code': 'NSE',
#   'high': 1574.3,
#   'low': 1573.3,
#   'open': 1573.7,
#   'stock_code': 'RELIND',
#   'volume': 102342},
#  {'close': 1573.6,
#   'datetime': '2026-01-01 13:25:00',
#   'exchange_code': 'NSE',
#   'high': 1574.2,
#   'low': 1573.5,
#   'open': 1573.7,
#   'stock_code': 'RELIND',
#   'volume': 43615},
#  {'close': 1574.1,
#   'datetime': '2026-01-01 13:26:00',
#   'exchange_code': 'NSE',
#   'high': 1574.1,
#   'low': 1573.0,
#   'open': 1573.5,
#   'stock_code': 'RELIND',
#   'volume': 44148},
#  {'close': 1574.7,
#   'datetime': '2026-01-01 13:27:00',
#   'exchange_code': 'NSE',
#   'high': 1575.0,
#   'low': 1574.0,
#   'open': 1574.1,
#   'stock_code': 'RELIND',
#   'volume': 6594},
#  {'close': 1575.9,
#   'datetime': '2026-01-01 13:28:00',
#   'exchange_code': 'NSE',
#   'high': 1575.9,
#   'low': 1574.7,
#   'open': 1575.1,
#   'stock_code': 'RELIND',
#   'volume': 18040},
#  {'close': 1575.7,
#   'datetime': '2026-01-01 13:29:00',
#   'exchange_code': 'NSE',
#   'high': 1576.2,
#   'low': 1575.4,
#   'open': 1575.9,
#   'stock_code': 'RELIND',
#   'volume': 107734},
#  {'close': 1576.1,
#   'datetime': '2026-01-01 13:30:00',
#   'exchange_code': 'NSE',
#   'high': 1576.3,
#   'low': 1575.3,
#   'open': 1575.7,
#   'stock_code': 'RELIND',
#   'volume': 46503},
#  {'close': 1575.9,
#   'datetime': '2026-01-01 13:31:00',
#   'exchange_code': 'NSE',
#   'high': 1576.7,
#   'low': 1575.8,
#   'open': 1576.4,
#   'stock_code': 'RELIND',
#   'volume': 51175},
#  {'close': 1577.0,
#   'datetime': '2026-01-01 13:32:00',
#   'exchange_code': 'NSE',
#   'high': 1577.2,
#   'low': 1575.7,
#   'open': 1576.2,
#   'stock_code': 'RELIND',
#   'volume': 27846},
#  {'close': 1576.2,
#   'datetime': '2026-01-01 13:33:00',
#   'exchange_code': 'NSE',
#   'high': 1577.4,
#   'low': 1576.2,
#   'open': 1577.0,
#   'stock_code': 'RELIND',
#   'volume': 13943},
#  {'close': 1576.2,
#   'datetime': '2026-01-01 13:34:00',
#   'exchange_code': 'NSE',
#   'high': 1576.9,
#   'low': 1576.2,
#   'open': 1576.5,
#   'stock_code': 'RELIND',
#   'volume': 1666},
#  {'close': 1577.3,
#   'datetime': '2026-01-01 13:35:00',
#   'exchange_code': 'NSE',
#   'high': 1577.4,
#   'low': 1576.0,
#   'open': 1576.5,
#   'stock_code': 'RELIND',
#   'volume': 24826},
#  {'close': 1577.0,
#   'datetime': '2026-01-01 13:36:00',
#   'exchange_code': 'NSE',
#   'high': 1577.3,
#   'low': 1577.0,
#   'open': 1577.0,
#   'stock_code': 'RELIND',
#   'volume': 2060},
#  {'close': 1577.5,
#   'datetime': '2026-01-01 13:37:00',
#   'exchange_code': 'NSE',
#   'high': 1577.5,
#   'low': 1577.0,
#   'open': 1577.0,
#   'stock_code': 'RELIND',
#   'volume': 3394},
#  {'close': 1576.6,
#   'datetime': '2026-01-01 13:38:00',
#   'exchange_code': 'NSE',
#   'high': 1577.3,
#   'low': 1576.3,
#   'open': 1577.2,
#   'stock_code': 'RELIND',
#   'volume': 53810},
#  {'close': 1576.5,
#   'datetime': '2026-01-01 13:39:00',
#   'exchange_code': 'NSE',
#   'high': 1577.0,
#   'low': 1576.5,
#   'open': 1577.0,
#   'stock_code': 'RELIND',
#   'volume': 2191},
#  {'close': 1576.0,
#   'datetime': '2026-01-01 13:40:00',
#   'exchange_code': 'NSE',
#   'high': 1576.7,
#   'low': 1576.0,
#   'open': 1576.5,
#   'stock_code': 'RELIND',
#   'volume': 9163},
# ...
#   'high': 1593.6,
#   'low': 1592.7,
#   'open': 1593.0,
#   'stock_code': 'RELIND',
#   'volume': 16026},
#  {'close': 1593.3,
#   'datetime': '2026-01-05 11:55:00',
#   'exchange_code': 'NSE',
#   'high': 1593.5,
#   'low': 1593.0,
#   'open': 1593.1,
#   'stock_code': 'RELIND',
#   'volume': 5888},
#  {'close': 1593.0,
#   'datetime': '2026-01-05 11:56:00',
#   'exchange_code': 'NSE',
#   'high': 1593.8,
#   'low': 1593.0,
#   'open': 1593.3,
#   'stock_code': 'RELIND',
#   'volume': 11258},
#  {'close': 1592.8,
#   'datetime': '2026-01-05 11:57:00',
#   'exchange_code': 'NSE',
#   'high': 1593.4,
#   'low': 1592.8,
#   'open': 1593.3,
#   'stock_code': 'RELIND',
#   'volume': 13163},
#  {'close': 1593.8,
#   'datetime': '2026-01-05 11:58:00',
#   'exchange_code': 'NSE',
#   'high': 1593.8,
#   'low': 1592.7,
#   'open': 1593.0,
#   'stock_code': 'RELIND',
#   'volume': 4673},
#  {'close': 1594.0,
#   'datetime': '2026-01-05 11:59:00',
#   'exchange_code': 'NSE',
#   'high': 1594.3,
#   'low': 1593.5,
#   'open': 1593.9,
#   'stock_code': 'RELIND',
#   'volume': 7978},
#  {'close': 1593.9,
#   'datetime': '2026-01-05 12:00:00',
#   'exchange_code': 'NSE',
#   'high': 1594.3,
#   'low': 1593.9,
#   'open': 1594.0,
#   'stock_code': 'RELIND',
#   'volume': 6384},
#  {'close': 1590.9,
#   'datetime': '2026-01-05 12:01:00',
#   'exchange_code': 'NSE',
#   'high': 1594.1,
#   'low': 1590.2,
#   'open': 1593.9,
#   'stock_code': 'RELIND',
#   'volume': 44153},
#  {'close': 1592.1,
#   'datetime': '2026-01-05 12:02:00',
#   'exchange_code': 'NSE',
#   'high': 1592.2,
#   'low': 1590.9,
#   'open': 1590.9,
#   'stock_code': 'RELIND',
#   'volume': 14120},
#  {'close': 1591.3,
#   'datetime': '2026-01-05 12:03:00',
#   'exchange_code': 'NSE',
#   'high': 1592.3,
#   'low': 1591.2,
#   'open': 1592.3,
#   'stock_code': 'RELIND',
#   'volume': 14925},
#  {'close': 1591.9,
#   'datetime': '2026-01-05 12:04:00',
#   'exchange_code': 'NSE',
#   'high': 1592.3,
#   'low': 1591.5,
#   'open': 1591.8,
#   'stock_code': 'RELIND',
#   'volume': 5908},
#  {'close': 1591.6,
#   'datetime': '2026-01-05 12:05:00',
#   'exchange_code': 'NSE',
#   'high': 1592.5,
#   'low': 1591.6,
#   'open': 1592.0,
#   'stock_code': 'RELIND',
#   'volume': 10780},
#  {'close': 1591.9,
#   'datetime': '2026-01-05 12:06:00',
#   'exchange_code': 'NSE',
#   'high': 1592.2,
#   'low': 1591.6,
#   'open': 1591.6,
#   'stock_code': 'RELIND',
#   'volume': 4641},
#  {'close': 1591.5,
#   'datetime': '2026-01-05 12:07:00',
#   'exchange_code': 'NSE',
#   'high': 1592.2,
#   'low': 1591.5,
#   'open': 1591.9,
#   'stock_code': 'RELIND',
#   'volume': 10468},
#  {'close': 1590.8,
#   'datetime': '2026-01-05 12:08:00',
#   'exchange_code': 'NSE',
#   'high': 1591.5,
#   'low': 1590.0,
#   'open': 1591.5,
#   'stock_code': 'RELIND',
#   'volume': 19523},
#  {'close': 1592.0,
#   'datetime': '2026-01-05 12:09:00',
#   'exchange_code': 'NSE',
#   'high': 1592.0,
#   'low': 1590.8,
#   'open': 1590.8,
#   'stock_code': 'RELIND',
#   'volume': 5644},
#  {'close': 1591.8,
#   'datetime': '2026-01-05 12:10:00',
#   'exchange_code': 'NSE',
#   'high': 1592.1,
#   'low': 1591.5,
#   'open': 1591.8,
#   'stock_code': 'RELIND',
#   'volume': 10310},
#  {'close': 1591.2,
#   'datetime': '2026-01-05 12:11:00',
#   'exchange_code': 'NSE',
#   'high': 1591.8,
#   'low': 1590.8,
#   'open': 1591.5,
#   'stock_code': 'RELIND',
#   'volume': 8314},
#  {'close': 1591.8,
#   'datetime': '2026-01-05 12:12:00',
#   'exchange_code': 'NSE',
#   'high': 1592.0,
#   'low': 1591.2,
#   'open': 1591.4,
#   'stock_code': 'RELIND',
#   'volume': 4939},
#  {'close': 1591.3,
#   'datetime': '2026-01-05 12:13:00',
#   'exchange_code': 'NSE',
#   'high': 1592.1,
#   'low': 1591.0,
#   'open': 1592.0,
#   'stock_code': 'RELIND',
#   'volume': 13703},
#  {'close': 1592.0,
#   'datetime': '2026-01-05 12:14:00',
#   'exchange_code': 'NSE',
#   'high': 1592.1,
#   'low': 1591.0,
#   'open': 1591.3,
#   'stock_code': 'RELIND',
#   'volume': 5315},
#  {'close': 1591.3,
#   'datetime': '2026-01-05 12:15:00',
#   'exchange_code': 'NSE',
#   'high': 1592.2,
#   'low': 1590.9,
#   'open': 1592.1,
#   'stock_code': 'RELIND',
#   'volume': 20481},
#  {'close': 1591.0,
#   'datetime': '2026-01-05 12:16:00',
#   'exchange_code': 'NSE',
#   'high': 1591.5,
#   'low': 1590.9,
#   'open': 1591.5,
#   'stock_code': 'RELIND',
#   'volume': 7124},
#  {'close': 1590.9,
#   'datetime': '2026-01-05 12:17:00',
#   'exchange_code': 'NSE',
#   'high': 1591.2,
#   'low': 1590.9,
#   'open': 1591.0,
#   'stock_code': 'RELIND',
#   'volume': 13857},
#  {'close': 1590.9,
#   'datetime': '2026-01-05 12:18:00',
#   'exchange_code': 'NSE',
#   'high': 1591.0,
#   'low': 1590.9,
#   'open': 1591.0,
#   'stock_code': 'RELIND',
#   'volume': 9757},
#  {'close': 1590.7,
#   'datetime': '2026-01-05 12:19:00',
#   'exchange_code': 'NSE',
#   'high': 1591.0,
#   'low': 1590.7,
#   'open': 1590.9,
#   'stock_code': 'RELIND',
#   'volume': 11980},
#  {'close': 1591.2,
#   'datetime': '2026-01-05 12:20:00',
#   'exchange_code': 'NSE',
#   'high': 1591.6,
#   'low': 1590.7,
#   'open': 1590.7,
#   'stock_code': 'RELIND',
#   'volume': 18557},
#  {'close': 1591.2,
#   'datetime': '2026-01-05 12:21:00',
#   'exchange_code': 'NSE',
#   'high': 1591.9,
#   'low': 1591.1,
#   'open': 1591.2,
#   'stock_code': 'RELIND',
#   'volume': 11707},
#  {'close': 1591.6,
#   'datetime': '2026-01-05 12:22:00',
#   'exchange_code': 'NSE',
#   'high': 1591.6,
#   'low': 1591.2,
#   'open': 1591.5,
#   'stock_code': 'RELIND',
#   'volume': 3533},
#  {'close': 1591.4,
#   'datetime': '2026-01-05 12:23:00',
#   'exchange_code': 'NSE',
#   'high': 1591.8,
#   'low': 1591.0,
#   'open': 1591.6,
#   'stock_code': 'RELIND',
#   'volume': 14087},
#  {'close': 1591.7,
#   'datetime': '2026-01-05 12:24:00',
#   'exchange_code': 'NSE',
#   'high': 1591.9,
#   'low': 1591.3,
#   'open': 1591.4,
#   'stock_code': 'RELIND',
#   'volume': 4194},
#  {'close': 1591.2,
#   'datetime': '2026-01-05 12:25:00',
#   'exchange_code': 'NSE',
#   'high': 1592.0,
#   'low': 1590.7,
#   'open': 1591.7,
#   'stock_code': 'RELIND',
#   'volume': 35136},
#  {'close': 1591.0,
#   'datetime': '2026-01-05 12:26:00',
#   'exchange_code': 'NSE',
#   'high': 1591.2,
#   'low': 1590.5,
#   'open': 1591.2,
#   'stock_code': 'RELIND',
#   'volume': 5173},
#  {'close': 1590.9,
#   'datetime': '2026-01-05 12:27:00',
#   'exchange_code': 'NSE',
#   'high': 1591.0,
#   'low': 1590.6,
#   'open': 1590.7,
#   'stock_code': 'RELIND',
#   'volume': 6531},
#  {'close': 1590.9,
#   'datetime': '2026-01-05 12:28:00',
#   'exchange_code': 'NSE',
#   'high': 1591.0,
#   'low': 1590.8,
#   'open': 1590.9,
#   'stock_code': 'RELIND',
#   'volume': 6527},
#  {'close': 1591.0,
#   'datetime': '2026-01-05 12:29:00',
#   'exchange_code': 'NSE',
#   'high': 1591.2,
#   'low': 1590.9,
#   'open': 1591.0,
#   'stock_code': 'RELIND',
#   'volume': 8427},
#  {'close': 1591.1,
#   'datetime': '2026-01-05 12:30:00',
#   'exchange_code': 'NSE',
#   'high': 1591.3,
#   'low': 1590.9,
#   'open': 1591.0,
#   'stock_code': 'RELIND',
#   'volume': 4527},
#  {'close': 1590.1,
#   'datetime': '2026-01-05 12:31:00',
#   'exchange_code': 'NSE',
#   'high': 1591.3,
#   'low': 1590.0,
#   'open': 1591.1,
#   'stock_code': 'RELIND',
#   'volume': 25743},
#  {'close': 1590.3,
#   'datetime': '2026-01-05 12:32:00',
#   'exchange_code': 'NSE',
#   'high': 1590.8,
#   'low': 1589.9,
#   'open': 1590.3,
#   'stock_code': 'RELIND',
#   'volume': 49352},
#  {'close': 1590.6,
#   'datetime': '2026-01-05 12:33:00',
#   'exchange_code': 'NSE',
#   'high': 1590.7,
#   'low': 1590.0,
#   'open': 1590.3,
#   'stock_code': 'RELIND',
#   'volume': 5999},
#  {'close': 1590.6,
#   'datetime': '2026-01-05 12:34:00',
#   'exchange_code': 'NSE',
#   'high': 1591.0,
#   'low': 1590.6,
#   'open': 1590.7,
#   'stock_code': 'RELIND',
#   'volume': 5074},
#  {'close': 1590.9,
#   'datetime': '2026-01-05 12:35:00',
#   'exchange_code': 'NSE',
#   'high': 1591.1,
#   'low': 1590.6,
#   'open': 1591.0,
#   'stock_code': 'RELIND',
#   'volume': 10193},
#  {'close': 1591.0,
#   'datetime': '2026-01-05 12:36:00',
#   'exchange_code': 'NSE',
#   'high': 1591.2,
#   'low': 1590.8,
#   'open': 1590.9,
#   'stock_code': 'RELIND',
#   'volume': 10241},
#  {'close': 1591.1,
#   'datetime': '2026-01-05 12:37:00',
#   'exchange_code': 'NSE',
#   'high': 1591.3,
#   'low': 1590.8,
#   'open': 1591.0,
#   'stock_code': 'RELIND',
#   'volume': 10359},
#  {'close': 1592.1,
#   'datetime': '2026-01-05 12:38:00',
#   'exchange_code': 'NSE',
#   'high': 1592.1,
#   'low': 1591.0,
#   'open': 1591.1,
#   'stock_code': 'RELIND',
#   'volume': 13940},
#  {'close': 1592.3,
#   'datetime': '2026-01-05 12:39:00',
#   'exchange_code': 'NSE',
#   'high': 1592.3,
#   'low': 1591.8,
#   'open': 1592.0,
#   'stock_code': 'RELIND',
#   'volume': 4790},
#  {'close': 1592.0,
#   'datetime': '2026-01-05 12:40:00',
#   'exchange_code': 'NSE',
#   'high': 1592.3,
#   'low': 1591.2,
#   'open': 1592.2,
#   'stock_code': 'RELIND',
#   'volume': 15518},
#  {'close': 1591.8,
#   'datetime': '2026-01-05 12:41:00',
#   'exchange_code': 'NSE',
#   'high': 1592.3,
#   'low': 1591.8,
#   'open': 1591.8,
#   'stock_code': 'RELIND',
#   'volume': 8044},
#  {'close': 1592.2,
#   'datetime': '2026-01-05 12:42:00',
#   'exchange_code': 'NSE',
#   'high': 1592.2,
#   'low': 1591.8,
#   'open': 1591.8,
#   'stock_code': 'RELIND',
#   'volume': 4954},
#  {'close': 1591.8,
#   'datetime': '2026-01-05 12:43:00',
#   'exchange_code': 'NSE',
#   'high': 1592.3,
#   'low': 1591.8,
#   'open': 1592.2,
#   'stock_code': 'RELIND',
#   'volume': 9173},
#  {'close': 1592.3,
#   'datetime': '2026-01-05 12:44:00',
#   'exchange_code': 'NSE',
#   'high': 1592.4,
#   'low': 1591.8,
#   'open': 1591.9,
#   'stock_code': 'RELIND',
#   'volume': 6829},
#  {'close': 1591.6,
#   'datetime': '2026-01-05 12:45:00',
#   'exchange_code': 'NSE',
#   'high': 1592.5,
#   'low': 1591.5,
#   'open': 1592.0,
#   'stock_code': 'RELIND',
#   'volume': 13234},
#  {'close': 1591.8,
#   'datetime': '2026-01-05 12:46:00',
#   'exchange_code': 'NSE',
#   'high': 1592.0,
#   'low': 1591.4,
#   'open': 1591.6,
#   'stock_code': 'RELIND',
#   'volume': 6546},
#  {'close': 1592.0,
#   'datetime': '2026-01-05 12:47:00',
#   'exchange_code': 'NSE',
#   'high': 1592.2,
#   'low': 1591.8,
#   'open': 1591.8,
#   'stock_code': 'RELIND',
#   'volume': 5738},
#  {'close': 1591.1,
#   'datetime': '2026-01-05 12:48:00',
#   'exchange_code': 'NSE',
#   'high': 1592.2,
#   'low': 1590.9,
#   'open': 1592.1,
#   'stock_code': 'RELIND',
#   'volume': 45362},
#  {'close': 1591.1,
#   'datetime': '2026-01-05 12:49:00',
#   'exchange_code': 'NSE',
#   'high': 1591.3,
#   'low': 1590.7,
#   'open': 1591.0,
#   'stock_code': 'RELIND',
#   'volume': 6840},
#  {'close': 1591.3,
#   'datetime': '2026-01-05 12:50:00',
#   'exchange_code': 'NSE',
#   'high': 1591.3,
#   'low': 1591.0,
#   'open': 1591.0,
#   'stock_code': 'RELIND',
#   'volume': 5163},
#  {'close': 1591.0,
#   'datetime': '2026-01-05 12:51:00',
#   'exchange_code': 'NSE',
#   'high': 1591.8,
#   'low': 1590.9,
#   'open': 1591.3,
#   'stock_code': 'RELIND',
#   'volume': 17714},
#  {'close': 1590.9,
#   'datetime': '2026-01-05 12:52:00',
#   'exchange_code': 'NSE',
#   'high': 1591.0,
#   'low': 1590.7,
#   'open': 1591.0,
#   'stock_code': 'RELIND',
#   'volume': 5662},
#  {'close': 1590.7,
#   'datetime': '2026-01-05 12:53:00',
#   'exchange_code': 'NSE',
#   'high': 1591.1,
#   'low': 1590.6,
#   'open': 1591.0,
#   'stock_code': 'RELIND',
#   'volume': 9948},
#  {'close': 1590.7,
#   'datetime': '2026-01-05 12:54:00',
#   'exchange_code': 'NSE',
#   'high': 1590.7,
#   'low': 1590.5,
#   'open': 1590.7,
#   'stock_code': 'RELIND',
#   'volume': 5383},
#  {'close': 1590.7,
#   'datetime': '2026-01-05 12:55:00',
#   'exchange_code': 'NSE',
#   'high': 1591.0,
#   'low': 1590.6,
#   'open': 1590.6,
#   'stock_code': 'RELIND',
#   'volume': 5556},
#  {'close': 1591.0,
#   'datetime': '2026-01-05 12:56:00',
#   'exchange_code': 'NSE',
#   'high': 1591.0,
#   'low': 1590.7,
#   'open': 1590.8,
#   'stock_code': 'RELIND',
#   'volume': 5553},
#  {'close': 1591.0,
#   'datetime': '2026-01-05 12:57:00',
#   'exchange_code': 'NSE',
#   'high': 1591.1,
#   'low': 1590.8,
#   'open': 1590.8,
#   'stock_code': 'RELIND',
#   'volume': 9713},
#  {'close': 1589.7,
#   'datetime': '2026-01-05 12:58:00',
#   'exchange_code': 'NSE',
#   'high': 1591.0,
#   'low': 1589.5,
#   'open': 1590.9,
#   'stock_code': 'RELIND',
#   'volume': 51887},
#  {'close': 1589.3,
#   'datetime': '2026-01-05 12:59:00',
#   'exchange_code': 'NSE',
#   'high': 1590.0,
#   'low': 1589.1,
#   'open': 1589.7,
#   'stock_code': 'RELIND',
#   'volume': 17029},
#  {'close': 1589.6,
#   'datetime': '2026-01-05 13:00:00',
#   'exchange_code': 'NSE',
#   'high': 1589.8,
#   'low': 1589.1,
#   'open': 1589.3,
#   'stock_code': 'RELIND',
#   'volume': 8988},
#  {'close': 1590.2,
#   'datetime': '2026-01-05 13:01:00',
#   'exchange_code': 'NSE',
#   'high': 1590.2,
#   'low': 1589.4,
#   'open': 1589.6,
#   'stock_code': 'RELIND',
#   'volume': 11389},
#  {'close': 1590.1,
#   'datetime': '2026-01-05 13:02:00',
#   'exchange_code': 'NSE',
#   'high': 1590.3,
#   'low': 1590.0,
#   'open': 1590.2,
#   'stock_code': 'RELIND',
#   'volume': 8235},
#  {'close': 1590.0,
#   'datetime': '2026-01-05 13:03:00',
#   'exchange_code': 'NSE',
#   'high': 1590.1,
#   'low': 1589.7,
#   'open': 1590.1,
#   'stock_code': 'RELIND',
#   'volume': 11153},
#  {'close': 1590.1,
#   'datetime': '2026-01-05 13:04:00',
#   'exchange_code': 'NSE',
#   'high': 1590.2,
#   'low': 1589.9,
#   'open': 1590.0,
#   'stock_code': 'RELIND',
#   'volume': 6678},
#  {'close': 1590.0,
#   'datetime': '2026-01-05 13:05:00',
#   'exchange_code': 'NSE',
#   'high': 1590.3,
#   'low': 1589.9,
#   'open': 1590.1,
#   'stock_code': 'RELIND',
#   'volume': 6628},
#  {'close': 1590.1,
#   'datetime': '2026-01-05 13:06:00',
#   'exchange_code': 'NSE',
#   'high': 1590.2,
#   'low': 1589.9,
#   'open': 1589.9,
#   'stock_code': 'RELIND',
#   'volume': 5711},
#  {'close': 1589.9,
#   'datetime': '2026-01-05 13:07:00',
#   'exchange_code': 'NSE',
#   'high': 1590.5,
#   'low': 1589.7,
#   'open': 1590.1,
#   'stock_code': 'RELIND',
#   'volume': 17824},
#  {'close': 1589.9,
#   'datetime': '2026-01-05 13:08:00',
#   'exchange_code': 'NSE',
#   'high': 1590.0,
#   'low': 1589.7,
#   'open': 1589.8,
#   'stock_code': 'RELIND',
#   'volume': 7448},
#  {'close': 1589.2,
#   'datetime': '2026-01-05 13:09:00',
#   'exchange_code': 'NSE',
#   'high': 1589.9,
#   'low': 1588.3,
#   'open': 1589.9,
#   'stock_code': 'RELIND',
#   'volume': 18483},
#  {'close': 1589.1,
#   'datetime': '2026-01-05 13:10:00',
#   'exchange_code': 'NSE',
#   'high': 1589.9,
#   'low': 1589.1,
#   'open': 1589.3,
#   'stock_code': 'RELIND',
#   'volume': 16504},
#  {'close': 1589.6,
#   'datetime': '2026-01-05 13:11:00',
#   'exchange_code': 'NSE',
#   'high': 1589.6,
#   'low': 1589.1,
#   'open': 1589.2,
#   'stock_code': 'RELIND',
#   'volume': 10305},
#  {'close': 1588.1,
#   'datetime': '2026-01-05 13:12:00',
#   'exchange_code': 'NSE',
#   'high': 1589.8,
#   'low': 1588.0,
#   'open': 1589.6,
#   'stock_code': 'RELIND',
#   'volume': 34640},
#  {'close': 1588.9,
#   'datetime': '2026-01-05 13:13:00',
#   'exchange_code': 'NSE',
#   'high': 1589.1,
#   'low': 1587.7,
#   'open': 1588.1,
#   'stock_code': 'RELIND',
#   'volume': 14761},
#  {'close': 1589.3,
#   'datetime': '2026-01-05 13:14:00',
#   'exchange_code': 'NSE',
#   'high': 1589.3,
#   'low': 1589.0,
#   'open': 1589.1,
#   'stock_code': 'RELIND',
#   'volume': 8658},
#  {'close': 1588.2,
#   'datetime': '2026-01-05 13:15:00',
#   'exchange_code': 'NSE',
#   'high': 1589.2,
#   'low': 1588.1,
#   'open': 1589.2,
#   'stock_code': 'RELIND',
#   'volume': 13370},
#  {'close': 1588.2,
#   'datetime': '2026-01-05 13:15:00',
#   'exchange_code': 'NSE',
#   'high': 1589.2,
#   'low': 1588.1,
#   'open': 1589.2,
#   'stock_code': 'RELIND',
#   'volume': 13370},
#  {'close': 1588.4,
#   'datetime': '2026-01-05 13:16:00',
#   'exchange_code': 'NSE',
#   'high': 1588.9,
#   'low': 1588.2,
#   'open': 1588.4,
#   'stock_code': 'RELIND',
#   'volume': 22655},
#  {'close': 1588.4,
#   'datetime': '2026-01-05 13:17:00',
#   'exchange_code': 'NSE',
#   'high': 1588.5,
#   'low': 1587.9,
#   'open': 1588.5,
#   'stock_code': 'RELIND',
#   'volume': 8399},
#  {'close': 1589.2,
#   'datetime': '2026-01-05 13:18:00',
#   'exchange_code': 'NSE',
#   'high': 1589.3,
#   'low': 1588.3,
#   'open': 1588.4,
#   'stock_code': 'RELIND',
#   'volume': 5806},
#  {'close': 1589.4,
#   'datetime': '2026-01-05 13:19:00',
#   'exchange_code': 'NSE',
#   'high': 1589.7,
#   'low': 1588.8,
#   'open': 1589.1,
#   'stock_code': 'RELIND',
#   'volume': 11009},
#  {'close': 1588.1,
#   'datetime': '2026-01-05 13:20:00',
#   'exchange_code': 'NSE',
#   'high': 1589.5,
#   'low': 1588.0,
#   'open': 1589.3,
#   'stock_code': 'RELIND',
#   'volume': 12933},
#  {'close': 1587.7,
#   'datetime': '2026-01-05 13:21:00',
#   'exchange_code': 'NSE',
#   'high': 1588.3,
#   'low': 1587.7,
#   'open': 1588.1,
#   'stock_code': 'RELIND',
#   'volume': 10047},
#  ...]
